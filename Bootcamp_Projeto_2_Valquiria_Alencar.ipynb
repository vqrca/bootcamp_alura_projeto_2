# %% [markdown]
# <a href="https://colab.research.google.com/github/vqrca/bootcamp_alura_projeto_2/blob/main/Bootcamp_Projeto_2_Valquiria_Alencar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Badge](https://img.shields.io/badge/Author-Valquíria_Alencar-%237159c1?style=flat-square&logo=ghost)](https://github.com/vqrca/) [![Gmail Badge](https://img.shields.io/badge/-valquiria.c.alencar@gmail.com-6633cc?style=flat-square&logo=Gmail&logoColor=white&link=mailto:valquiria.c.alencar@gmail.com)](mailto:valquiria.c.alencar@gmail.com) [![Linkedin Badge](https://img.shields.io/badge/-Valquíria_Alencar-6633cc?style=flat-square&logo=Linkedin&logoColor=white&link=https://www.linkedin.com/in/valquiria-alencar/)](https://www.linkedin.com/in/valquiria-alencar/)
#
# #**Introdução**
#
# Neste projeto estou aplicando os conhecimentos obtidos  nos módulos 1 e 2 do Bootcamp de Data Science Aplicada da Alura, analisando os dados do [Programa Nacional de Imunizações](http://tabnet.datasus.gov.br/cgi/tabcgi.exe?pni/cnv/cpniuf.def). As análises realizadas aqui envolvem a cobertura vacinal das vacinas incluídas nos calendários de vacinação do SUS (Sistema Único de Saúde). Além disso, foi feita uma análise mais profunda em relação à vacinação contra o HPV (Human papillomavirus - Papilomavírus Humano).
#
# Um PDF sumarizando as análises, sem conter os códigos e etapas de tratamento dos dados, pode ser encontrado [aqui]().
#
# ## **O que é o Programa Nacional de Imunizações?**
#
# O Programa Nacional de Imunizações (PNI) envolve a distribuição anual de mais de 300 milhões de doses de vacinas, soros e imunoglobulinas. Esse programa é extremamente importante, pois contribuiu, por exemplo, com a erradicação da varíola e da poliomielite, além da redução dos casos e mortes derivadas do sarampo, da rubéola, do tétano, da difteria e da coqueluche.
#
# O PNI define os calendários de vacinação considerando a situação epidemiológica, o risco, a vulnerabilidade e as especificidades sociais. O programa sempre segue com orientações específicas para crianças, adolescentes, adultos, gestantes, idosos e povos indígenas. E, para que o programa continue representando um sucesso na saúde pública, cada vez mais esforços devem ser despendidos.
#
# Todas as doenças prevenidas pelas vacinas que constam no calendário de vacinação, se não forem alvo de ações prioritárias, podem voltar a se tornar recorrentes. E atualmente, temos outro problema: narrativas falsas e sem nenhuma comprovação científica, têm se disseminado pelas redes sociais, dando sustentação ao discurso do movimento antivacina.
#
# ## **O que é cobertura vacinal?**
#
# A cobertura vacinal é o número de doses aplicadas (correspondente ao esquema completo de vacinação) de determinado imunobiológico dividido pela população alvo e multiplicado por 100, em uma área e tempo considerados. Este indicador corresponde ao percentual de pessoas vacinadas e potencialmente protegidas contra determinada doença.
#
# ## **O que é HPV?**
#
# O papilomavírus humano, conhecido como HPV, é um vírus que se instala na pele ou em mucosas. Sua ação pode provocar infecções e o câncer de colo do útero.
#
# - Há mais de 100 diferentes tipos de HPV. Alguns tipos de HPV podem provocar câncer e outros podem causar verrugas genitais.
#
# - Existem 12 tipos identificados como de alto risco (HPV tipos 16, 18, 31, 33, 35, 39, 45, 51, 52, 56, 58 e 59) que têm probabilidade maior de persistir e estar associados a lesões pré- cancerígenas.
#
# - O HPV de tipos 16 e 18 causam a maioria dos casos de câncer de colo do útero em todo o mundo (cerca de 70%).
#
# - O câncer de colo do útero é uma doença grave que pode levar ao óbito. No Brasil, é a quarta maior causa de morte entre as mulheres.
#
# - Em 2019, ocorreram 6.596 óbitos por esta neoplasia, representando uma taxa ajustada de mortalidade por este câncer de 5.33/100 mil mulheres.
#
# ### **Transmissão do HPV:**
# - A transmissão do vírus ocorre por contato direto com a pele ou mucosa infectada.
#
# - A principal forma de transmissão é pela via sexual, que inclui contato oral-genital, genital-genital ou mesmo manual-genital. Portanto, o contágio com o HPV pode ocorrer mesmo na ausência de penetração vaginal ou anal.
#
# - Também pode ocorrer transmissão durante o parto.
#
# - Não está comprovada a possibilidade de contaminação por meio de objetos, do uso de vaso sanitário e piscina ou pelo compartilhamento de toalhas e roupas íntimas.
#
# ### **Vacinação contra o HPV:**
# - A vacina HPV quadrivalente proporciona proteção contra HPV 6, 11, 16 e 18, então, abrange os dois principais tipos responsáveis pelo câncer de colo do útero. Com isso, a fim reforçar as atuais ações de prevenção do câncer de colo do útero, o Ministério da Saúde, com as Secretarias Estaduais e Municipais de Saúde, dá continuidade à estratégia de vacinação contra o HPV.
#
# - Essa vacina foi incluída no Calendário Nacional de Vacinação do SUS em março de 2014, tendo como população-alvo as meninas de 11 a 13 anos de idade. No entanto, em 2015, a oferta da vacina foi ampliada para as meninas na faixa etária de 9 a 13 anos de idade.
#
# - O Ministério da Saúde adotava o esquema vacinal estendido, composto por três doses (0, 6 e 60 meses), entretanto, para meninas de 9 a 13 anos, o esquema vacinal mudou para duas doses (0 e 6 meses). A mudança se deu com base em estudos que comprovaram a efetividade da imunização em duas doses em meninas nessa faixa etária. Para as demais faixas etárias devem ser aplicadas as três doses. A vacinação poderá ocorrer nas Unidades de Saúde do SUS e em parceria com as Secretarias de Saúde e Educação.
#
# - É importante destacar que a vacina também é aplicada em indivíduos do sexo masculino e que essa vacina possui maior indicação para essa faixa etária (9-13 anos), pois considera que os individuos ainda não iniciaram a vida sexual, uma vez que a vacina apresenta maior eficácia na proteção de indivíduos não expostos aos tipos virais presentes nas vacinas.
#
# - A vacina para o sexo masculino é importante para oferecer proteção contra as verrugas genitais, associadas à infecção pelos tipos 6 e 11 do HPV, que, além dos prejuízos estéticos e do desconforto, podem aumentar o risco de transmissão de HIV. Além disso, uma vez vacinado, o homem terá menos chances de transmitir o vírus para a mulher, ampliando a eficácia geral da vacina. No entanto, a vacina ainda é pouco difundida entre os homens.

# %% [markdown]
# # **Objetivos**
#
# O projeto aqui apresentado teve por objetivo analisar a cobertura da vacinação nas Unidades da Federação por ano, no período disponibilizado pelo DATASUS (1994-2019) e verificar a cobertura dos imunobiológicos aplicados em cada uma das Unidades da Federação.
# >**Você pode acessar todos os resultados desse tema [aqui](#results1)**
#
# Além disso, como a vacinação contra HPV não está incluída nos dados de cobertura vacinal, outros datasets foram obtidos, como os seguintes objetivos:
#
# - Verificar se houve aumento na aplicação de doses após o período que a vacina foi incluída no calendário de vacinação;
# - Comparar a aplicação de doses nos sexos feminino e masculino e verificar se houve aumento de adesão no sexo masculino ao longo do tempo;
# - Analisar a proporcionalidade da vacinação de acordo com o número de habitantes e verificar se há consistência nessas proporções nas Unidades da Federação;
# - Analisar o número de doses aplicadas por faixa etária.
# >**Você pode acessar todos os resultados desse tema [aqui](#results2)**

# %% [markdown]
# # **Métodos**
#
# ## **Coleta dos dados:**
#
# Os dados utilizados neste projeto foram obtidos do [Tabnet - DATASUS](http://www2.datasus.gov.br/DATASUS/index.php?area=0202&id=11637), um banco de dados que disponibiliza dados relacionados à saúde. Entre os dados disponibilizados, podemos encontrar  Imunizações - desde 1994, na opção Assistência à saúde. Em imunizações há dados sobre cobertura vacinal, número de doses aplicadas e taxas de abandono.
#
# Neste projeto os seguintes datasets foram obtidos:
#
# ### **Coberturas Vacinais por Ano segundo Unidade da Federação**
# Aplicando os seguintes filtros:
#
# - Linha: Unidade da Federação
#
# - Coluna: Ano
#
# - Conteúdo: Coberturas Vacinais
#
# - Período disponível: 1994 - 2019
#
# ### **Coberturas Vacinais por Imunobiológico segundo Unidade da Federação**
# Aplicando os seguintes filtros:
#
# - Linha: Unidade da Federação
#
# - Coluna: Imuno
#
# - Conteúdo: Coberturas Vacinais
#
# - Período disponível: 1994 - 2019
#
# ### **HPV - Doses aplicadas: Imunobiológicos: HPV Quadrivalente - Feminino/Masculino**
# **por ano:**
#
# - Linha: Unidade da Federação
#
# - Coluna: Ano
#
# - Conteúdo: Doses aplicadas
#
# - Período disponível: 2009-20219 (feminino), 2013-2019 (masculino)
#
#
# **por faixa etária:**
#
# - Linha: Unidade da Federação
#
# - Coluna: Faixa etária
#
# - Conteúdo: Doses aplicadas
#
# - Período disponível: 2009-2019 (feminino), 2013-2019 (masculino)
#
#
# > **Os datasets sobre HPV estavam disponíveis apenas na opção [Doses aplicadas](http://tabnet.datasus.gov.br/cgi/dhdat.exe?bd_pni/dpnibr.def)**

# %% [markdown]
# # **O que você vai ver daqui pra frente?**
#
# A seguir você vai encontrar um projeto que foi dividido em duas partes:
#
# - Parte I: Análise da cobertura da vacinação no Brasil por ano e exploração da cobertura vacinal der vários imunobiológicos
#
# - Parte II: Vou detalhar a Vacinação contra HPV
#
#
# **A Estrutura do notebook é a seguinte:**
#
# - Importação dos dados
#
#   [Parte I](#imp1)
#
#   [Parte II](#imp2)
#
# - Análise exploratória
#
#   [Parte I](#exp1)
#
#   [Parte II](#exp2)
#
# - Tratamento das bases de dados
#
#   [Parte I](#trat1)
#
#   [Parte II](#trat2)
#
# - Análises dos dados e todos os resultados obtidos
#
#   [Parte I](#results1)
#
#   [Parte II](#results2)
#
# - [Conclusões](#conc)
#
# - [Considerações finais](#final)
#
# - [Referências](#ref)
#
# - [Documentação](#doc)
#
# - [Agradecimentos](#agra)

# %% [markdown]
# #**Importando as bibliotecas**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import ticker
from matplotlib.colors import ListedColormap
import seaborn as sns
import numpy as np
from bs4 import BeautifulSoup 
import requests 
import warnings
warnings.filterwarnings('ignore')

# %%
# Configuração das cores utilizadas nos gráficos: 
GRAY1, GRAY2, GRAY3 = '#231F20', '#414040', '#555655'
GRAY4, GRAY5, GRAY6 = '#646369', '#76787B', '#828282'
GRAY7, GRAY8, GRAY9 = '#929497', '#A6A6A5', '#BFBEBE'
BLUE1, BLUE2, BLUE3, BLUE4 = '#174A7E', '#4A81BF', '#94B2D7', '#94AFC5'
RED1, RED2 = '#C3514E', '#E6BAB7'
GREEN1, GREEN2 = '#0C8040', '#9ABB59'

# %% [markdown]
# #**Parte I:**
# ### **Análise da cobertura da vacinação nas Unidades da Federação por ano, no período disponibilizado pelo DATASUS (1994-2019) e exploração da cobertura dos imunobiológicos aplicados em cada uma das Unidades da Federação.**
#
# > **Você pode acessar todos os resultados desse tema [aqui](#results1).**

# %% [markdown]
# <a name="imp1"></a>
# ##**Importando os dados**:
# Os dados estão disponíveis no [Github](https://github.com/vqrca/bootcamp_alura_projeto_2/blob/main/Dados).

# %% [markdown]
# Para carregar a base de dados foi necessário mudar o enconding dos dados para `encoding="ISO-8859-1"`. A indicação de separação do texto foi feita com `sep= ";"` e os decimais foram definidos `decimal =","`. Para retirar linhas desnecessárias foi necessário usar os comandos `skiprows=3` e `skipfooter=19`.

# %% [markdown]
# ###**Cobertura Vacinal por Ano:**

# %%
dados_ano = pd.read_csv('https://raw.githubusercontent.com/vqrca/bootcamp_alura_projeto_2/main/Dados/cobertura_vacinas_1994-2021_por_ano.csv', 
                        encoding='ISO-8859-1', skiprows=3, sep=';', skipfooter = 19, thousands='.', decimal =',')
dados_ano
# Out:
#       Unidade da Federação   1994   1995   1996  ...   2017   2018   2019  Total
# 0              11 Rondônia  42.76  50.80  76.05  ...  80.74  82.45  51.44  79.88
# 1                  12 Acre  20.53  46.61  36.59  ...  62.18  67.44  45.44  69.26
# 2              13 Amazonas  20.15  35.82  49.88  ...  65.33  69.82  49.97  69.65
# 3               14 Roraima  64.06  88.84  89.18  ...  74.26  78.76  48.04  75.68
# 4                  15 Pará  32.44  40.11  51.26  ...  57.60  57.44  37.53  73.89
# 5                 16 Amapá    NaN  34.68  44.75  ...  58.66  63.32  44.02  72.88
# 6             17 Tocantins    NaN    NaN  65.44  ...  81.70  82.32  57.59  78.47
# 7              21 Maranhão  27.43  35.69  41.05  ...  60.87  64.51  40.05  73.91
# 8                 22 Piauí  62.22  48.16  46.40  ...  67.25  70.80  44.88  73.15
# 9                 23 Ceará  49.20  50.06  60.28  ...  73.67  77.37  47.53  75.75
# 10  24 Rio Grande do Norte  41.34  49.23  56.57  ...  53.69  67.54  38.10  68.77
# ...

# %% [markdown]
# ###**Cobertura Vacinal por Imunobiológico:**

# %% [markdown]
# Para carregar a base de dados foi necessário mudar o enconding dos dados para `encoding="ISO-8859-1"`. A indicação de separação do texto foi feita com `sep= ";"` e os decimais foram definidos `decimal =","`.

# %%
dados_imuno = pd.read_csv('https://github.com/vqrca/bootcamp_alura_projeto_2/blob/main/Dados/cobertura_vacinas_1994-2021_por_imuno.csv?raw=True', encoding='ISO-8859-1', 
                      sep=';', decimal =',')
dados_imuno
# Out:
#       Unidade da Federação     BCG  ...  Ignorado   Total
# 0              11 Rondônia  104.23  ...     78.44   80.76
# 1                  12 Acre  104.21  ...     73.78   69.83
# 2              13 Amazonas  107.67  ...     69.99   70.96
# 3               14 Roraima  112.94  ...     77.16   76.72
# 4                  15 Pará  109.26  ...     82.34   74.27
# 5                 16 Amapá  112.59  ...     75.22   72.45
# 6             17 Tocantins  105.86  ...     79.24   79.03
# 7              21 Maranhão  111.95  ...     79.04   74.07
# 8                 22 Piauí  101.81  ...     77.51   73.72
# 9                 23 Ceará  109.27  ...     77.77   76.97
# 10  24 Rio Grande do Norte  102.79  ...     74.39   69.72
# 11              25 Paraíba  105.55  ...     77.31   72.84
# 12           26 Pernambuco  112.18  ...     80.06   75.94
# 13              27 Alagoas  103.86  ...     77.92   71.40
# 14              28 Sergipe  103.88  ...     79.55   74.94
# ...

# %% [markdown]
# ##**Estrutura dos dados**

# %% [markdown]
# ###**Cobertura Vacinal por Ano:**

# %% [markdown]
# O DataFrame possui nas linhas as 27 Unidades de Federação e 25 colunas contendo as porcentagens de cobertura vacinal (no tipo float) para cada no (1994 até 2019).
# Além disso, temos uma coluna denominada 'Total':

# %%
dados_ano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unidade da Federação  28 non-null     object
#  1   1994                  16 non-null     float64
#  2   1995                  25 non-null     float64
#  3   1996                  27 non-null     float64
#  4   1997                  28 non-null     float64
#  5   1998                  28 non-null     float64
#  6   1999                  28 non-null     float64
#  7   2000                  28 non-null     float64
#  8   2001                  28 non-null     float64
#  9   2002                  28 non-null     float64
#  10  2003                  28 non-null     float64
#  11  2004                  28 non-null     float64
#  12  2005                  28 non-null     float64
#  13  2006                  28 non-null     float64
# ...

# %% [markdown]
# ###**Cobertura Vacinal por Imunobiológico:**

# %% [markdown]
# O DataFrame possui nas linhas as 27 Unidades de Federação e 25 colunas contendo as porcentagens de cobertura vacinal (no tipo float) para cada Imunobiológico, desde 1994 até 2019.
# Além disso, temos uma coluna denominada 'Ignorado' e a última denominada 'Total':

# %%
dados_imuno.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unidade da Federação                       28 non-null     object
#  1   BCG                                        28 non-null     float64
#  2   Hepatite B  em crianças até 30 dias        28 non-null     float64
#  3   Rotavírus Humano                           28 non-null     float64
#  4   Meningococo C                              28 non-null     float64
#  5   Hepatite B                                 28 non-null     float64
#  6   Penta                                      28 non-null     float64
#  7   Pneumocócica                               28 non-null     float64
#  8   Poliomielite                               28 non-null     float64
#  9   Poliomielite 4 anos                        28 non-null     float64
# ...

# %% [markdown]
# <a name="exp1"></a>
# ## **Análise exploratória dos dados**

# %% [markdown]
# ###**Cobertura Vacinal por Ano:**

# %% [markdown]
# Esse DataFrame possui alguns dados denominados NaN (*Not a Number*).
# NaN é um valor ou símbolo usado nas linguagens de programação para representar um valor numérico indefinido ou irrepresentável:

# %%
dados_ano.isnull
# Out:
# <bound method DataFrame.isnull of       Unidade da Federação   1994   1995   1996  ...   2017   2018   2019  Total
# 0              11 Rondônia  42.76  50.80  76.05  ...  80.74  82.45  51.44  79.88
# 1                  12 Acre  20.53  46.61  36.59  ...  62.18  67.44  45.44  69.26
# 2              13 Amazonas  20.15  35.82  49.88  ...  65.33  69.82  49.97  69.65
# 3               14 Roraima  64.06  88.84  89.18  ...  74.26  78.76  48.04  75.68
# 4                  15 Pará  32.44  40.11  51.26  ...  57.60  57.44  37.53  73.89
# 5                 16 Amapá    NaN  34.68  44.75  ...  58.66  63.32  44.02  72.88
# 6             17 Tocantins    NaN    NaN  65.44  ...  81.70  82.32  57.59  78.47
# 7              21 Maranhão  27.43  35.69  41.05  ...  60.87  64.51  40.05  73.91
# 8                 22 Piauí  62.22  48.16  46.40  ...  67.25  70.80  44.88  73.15
# 9                 23 Ceará  49.20  50.06  60.28  ...  73.67  77.37  47.53  75.75
# ...

# %% [markdown]
# Utilizando `.describe` podemos ter uma visão geral do dataframe, com a média dos valores, desvio padrão, valores mínimos e máximos.

# %%
dados_ano.describe()
# Out:
#             1994       1995       1996  ...       2018       2019      Total
# count  16.000000  25.000000  27.000000  ...  28.000000  28.000000  28.000000
# mean   39.736875  47.111200  53.807778  ...  72.652857  46.716071  74.043214
# std    14.031838  19.399374  13.961216  ...   7.281815   6.982667   3.098723
# min    20.150000   0.340000  36.260000  ...  57.440000  25.990000  68.770000
# 25%    30.677500  35.690000  44.805000  ...  68.455000  44.200000  71.935000
# 50%    39.805000  45.700000  50.000000  ...  71.685000  46.295000  74.135000
# 75%    49.800000  55.470000  62.860000  ...  77.717500  50.337500  75.835000
# max    64.060000  88.840000  89.180000  ...  85.420000  60.590000  79.880000
#
# [8 rows x 27 columns]

# %% [markdown]
# Ao verificar em quais anos houve maiores médias dos valores de cobertura vacinal, vemos que aos anos com valores mais altos foram:
# - 2015
# - 1999
# - 2014
# - 2011
# - 2004

# %%
dados_ano.mean().sort_values(ascending=False)
# Out:
# 2015     93.703214
# 1999     85.585000
# 2014     85.481071
# 2011     84.799643
# 2004     81.136786
# 2001     80.434643
# 2007     78.594643
# 2009     78.226786
# 2005     77.356429
# 2002     77.126786
# 2012     76.821786
# 2006     76.687143
# 2000     76.613929
# 2010     75.419286
# 2008     75.306071
# Total    74.043214
# 2003     73.893214
# 2018     72.652857
# 1998     72.474286
# 2013     72.425357
# 2017     69.115357
# 1997     68.178929
# 1996     53.807778
# 2016     52.646071
# 1995     47.111200
# 2019     46.716071
# 1994     39.736875
# dtype: float64

# %% [markdown]
# ###**Cobertura Vacinal por Imunobiológico:**

# %% [markdown]
# Utilizando `.describe` podemos ter uma visão geral do dataframe, com a média dos valores, desvio padrão, valores mínimos e máximos.

# %%
dados_imuno.describe()
# Out:
#               BCG  Hepatite B  em crianças até 30 dias  ...    Ignorado      Total
# count   28.000000                            28.000000  ...   28.000000  28.000000
# mean   105.708214                            73.003214  ...   77.430714  75.225000
# std      4.055955                             7.627134  ...    5.509290   3.627929
# min     99.020000                            62.850000  ...   69.990000  69.720000
# 25%    102.685000                            69.077500  ...   74.600000  72.742500
# 50%    104.855000                            71.630000  ...   77.235000  74.745000
# 75%    108.967500                            78.395000  ...   78.762500  77.432500
# max    112.940000                            93.620000  ...  101.360000  84.540000
#
# [8 rows x 27 columns]

# %% [markdown]
# Analisando os valores de média da % da Cobertura vacinal, em ordem decrescente:

# %%
dados_imuno.mean().sort_values(ascending=False)
# Out:
# BCG                                          105.708214
# Tríplice Viral  D1                            99.314286
# Poliomielite                                  93.092857
# DTP                                           86.180357
# Meningococo C (1º ref)                        82.699643
# Pneumocócica                                  82.145000
# Sarampo                                       81.514286
# Pneumocócica(1º ref)                          80.731071
# Hepatite B                                    78.783571
# Penta                                         78.214643
# Ignorado                                      77.430714
#  Total                                        75.225000
# Poliomielite(1º ref)                          75.198214
# Tríplice Bacteriana(DTP)(1º ref)              73.381429
# Hepatite B  em crianças até 30 dias           73.003214
# Tríplice Viral  D2                            72.693929
# Tetravalente (DTP/Hib) (TETRA)                72.139286
# ...

# %% [markdown]
# Quando analisamos os valores de **média** vemos que os Imunobiológicos com **maiores % de cobertura vacinal** são:
#
# - BCG
# - Tríplice Viral  D1
# - Poliomielite
# - DTP
#
# Quando analisamos os valores de **média** vemos que os Imunobiológicos com % de Cobertura vacinal **abaixo de 50%** são:
#
# - Febre Amarela
# - Dupla adulto e tríplice acelular gestante
# - dTpa gestante
# - DTP REF (4 e 6 anos)
# - Haemophilus influenzae b

# %%
ax= dados_imuno.mean().sort_values(ascending=True).plot(kind='barh', figsize=(10,6), color='mediumseagreen')
ax.tick_params(color = 'darkgrey', bottom = 'off')
ax.spines['bottom'].set_color('darkgrey')
ax.spines['left'].set_color('darkgrey')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xticks(fontsize=14, rotation=360, color=GRAY4)
plt.yticks(fontsize=10, color=GRAY2)
plt.xlabel('Cobertura vacinal %', fontsize=12, color=GRAY2)
plt.show()

# %% [markdown]
# Analisando os valores de desvio-padrão da % da Cobertura vacinal, em ordem decrescente:

# %%
dados_imuno.std().sort_values(ascending=False)
# Out:
# Febre Amarela                                34.403254
# Sarampo                                      16.678842
# Poliomielite 4 anos                          15.015226
# Tetra Viral(SRC+VZ)                          13.738722
# Tríplice Viral  D2                            9.069473
# Poliomielite(1º ref)                          8.708751
# Pneumocócica                                  8.499042
# Pneumocócica(1º ref)                          8.412269
# Dupla adulto e tríplice acelular gestante     8.166376
# Meningococo C (1º ref)                        8.127147
# Hepatite B                                    7.797640
# Hepatite B  em crianças até 30 dias           7.627134
# Penta                                         7.594176
# Tríplice Bacteriana(DTP)(1º ref)              7.403173
# Hepatite A                                    6.976707
# Meningococo C                                 6.956664
# Tríplice Viral  D1                            6.543972
# ...

# %% [markdown]
# Quando analisamos os valores de desvio-padrão vemos que os Imunobiológicos com **maiores discrepâncias na % de Cobertura vacinal** são:
#
# - Febre Amarela
# - Sarampo
# - Poliomielite 4 anos
# - Tetra Viral(SRC+VZ)

# %% [markdown]
# <a name="trat1"></a>
# ##**Tratamento das bases de dados**

# %% [markdown]
# ###**Cobertura Vacinal por Ano:**

# %% [markdown]
# Os dados nulos NaN foram preenchidos utilizando o método backfill:

# %%
dados_ano_sem_na = dados_ano.fillna(method='backfill') 
dados_ano_sem_na
# Out:
#       Unidade da Federação   1994   1995   1996  ...   2017   2018   2019  Total
# 0              11 Rondônia  42.76  50.80  76.05  ...  80.74  82.45  51.44  79.88
# 1                  12 Acre  20.53  46.61  36.59  ...  62.18  67.44  45.44  69.26
# 2              13 Amazonas  20.15  35.82  49.88  ...  65.33  69.82  49.97  69.65
# 3               14 Roraima  64.06  88.84  89.18  ...  74.26  78.76  48.04  75.68
# 4                  15 Pará  32.44  40.11  51.26  ...  57.60  57.44  37.53  73.89
# 5                 16 Amapá  27.43  34.68  44.75  ...  58.66  63.32  44.02  72.88
# 6             17 Tocantins  27.43  35.69  65.44  ...  81.70  82.32  57.59  78.47
# 7              21 Maranhão  27.43  35.69  41.05  ...  60.87  64.51  40.05  73.91
# 8                 22 Piauí  62.22  48.16  46.40  ...  67.25  70.80  44.88  73.15
# 9                 23 Ceará  49.20  50.06  60.28  ...  73.67  77.37  47.53  75.75
# 10  24 Rio Grande do Norte  41.34  49.23  56.57  ...  53.69  67.54  38.10  68.77
# ...

# %% [markdown]
# Definindo 'Unidade da Federação' como index:

# %%
dados_ano_final = dados_ano_sem_na.set_index('Unidade da Federação')
dados_ano_final.head()
# Out:
#                        1994   1995   1996   1997  ...   2017   2018   2019  Total
# Unidade da Federação                              ...
# 11 Rondônia           42.76  50.80  76.05  83.33  ...  80.74  82.45  51.44  79.88
# 12 Acre               20.53  46.61  36.59  67.56  ...  62.18  67.44  45.44  69.26
# 13 Amazonas           20.15  35.82  49.88  72.01  ...  65.33  69.82  49.97  69.65
# 14 Roraima            64.06  88.84  89.18  80.26  ...  74.26  78.76  48.04  75.68
# 15 Pará               32.44  40.11  51.26  67.09  ...  57.60  57.44  37.53  73.89
#
# [5 rows x 27 columns]

# %% [markdown]
# Remoção da coluna 'Total' e da linha 'Total':

# %%
dados_ano_final2 = dados_ano_final.drop('Total', axis=0)
dados_ano_final3 = dados_ano_final2.drop('Total', axis=1)
dados_ano_final3.tail()
# Out:
#                         1994   1995   1996   1997  ...   2016   2017   2018   2019
# Unidade da Federação                               ...
# 43 Rio Grande do Sul   31.76  65.25  58.90  65.07  ...  53.86  72.54  74.94  51.65
# 50 Mato Grosso do Sul  31.76  37.67  39.02  70.62  ...  63.55  78.81  83.52  52.21
# 51 Mato Grosso         31.76  37.67  37.44  74.22  ...  58.32  74.28  76.70  46.38
# 52 Goiás               22.37  69.81  66.93  70.07  ...  53.60  73.25  71.85  47.04
# 53 Distrito Federal    38.27   0.34  55.99  64.17  ...  75.28  73.82  73.85  49.58
#
# [5 rows x 26 columns]

# %% [markdown]
# Retirando os números que antecedem os nomes das Unidades da Federação:

# %%
dados_ano_final3.index = dados_ano_final3.index.str[3:] #retirar as três primeiras strings
dados_ano_final3.index
# Out:
# Index(['Rondônia', 'Acre', 'Amazonas', 'Roraima', 'Pará', 'Amapá', 'Tocantins',
#        'Maranhão', 'Piauí', 'Ceará', 'Rio Grande do Norte', 'Paraíba',
#        'Pernambuco', 'Alagoas', 'Sergipe', 'Bahia', 'Minas Gerais',
#        'Espírito Santo', 'Rio de Janeiro', 'São Paulo', 'Paraná',
#        'Santa Catarina', 'Rio Grande do Sul', 'Mato Grosso do Sul',
#        'Mato Grosso', 'Goiás', 'Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %% [markdown]
# Agora o que eu vou fazer é o seguinte: alterar o dataset para pegar essas várias variáveis, que são as Unidades da Federação, e transformá-las em linhas extras. Portanto, se antes eu tinha uma única linha, agora eu vou ter 27 linhas para cada uma dessas variáveis.
#
# Isso é feito com a função `melt()`:

# %%
cobertura_aberto = dados_ano_final3.reset_index().melt(id_vars=["Unidade da Federação"], value_vars=dados_ano_final3.columns)

# %% [markdown]
# Definindo os nomes das colunas:

# %%
cobertura_aberto.columns = ["uf", "ano", "cobertura"]
cobertura_aberto.head()
# Out:
#          uf   ano  cobertura
# 0  Rondônia  1994      42.76
# 1      Acre  1994      20.53
# 2  Amazonas  1994      20.15
# 3   Roraima  1994      64.06
# 4      Pará  1994      32.44

# %% [markdown]
# Organizando os tipos para ano e cobertura, com `datetime64` e `float`, respectivamente:

# %%
cobertura_aberto["ano"] = cobertura_aberto["ano"].astype(str).astype("datetime64[ns]")

# %%
cobertura_aberto["cobertura"] = cobertura_aberto["cobertura"].astype(float)

# %% [markdown]
# ###**Cobertura Vacinal por Imunobiológico:**

# %%
dados_imuno.head()
# Out:
#   Unidade da Federação     BCG  ...  Ignorado   Total
# 0          11 Rondônia  104.23  ...     78.44   80.76
# 1              12 Acre  104.21  ...     73.78   69.83
# 2          13 Amazonas  107.67  ...     69.99   70.96
# 3           14 Roraima  112.94  ...     77.16   76.72
# 4              15 Pará  109.26  ...     82.34   74.27
#
# [5 rows x 28 columns]

# %% [markdown]
# Definindo 'Unidade da Federação' como index:

# %%
dados_im = dados_imuno.set_index('Unidade da Federação')
dados_im.head()
# Out:
#                          BCG  ...   Total
# Unidade da Federação          ...
# 11 Rondônia           104.23  ...   80.76
# 12 Acre               104.21  ...   69.83
# 13 Amazonas           107.67  ...   70.96
# 14 Roraima            112.94  ...   76.72
# 15 Pará               109.26  ...   74.27
#
# [5 rows x 27 columns]

# %% [markdown]
# Retirando:
#
# linha: 'Total'
#
# colunas: 'Ignorado' e 'Total'

# %%
dados_im_semtotal = dados_im.drop('Total', axis=0)
dados_im_semtotal = dados_im_semtotal.drop('Ignorado', axis=1)
dados_im_final = dados_im_semtotal.drop(' Total', axis=1)

dados_im_final
# Out:
#                            BCG  ...  Tetravalente (DTP/Hib) (TETRA)
# Unidade da Federação            ...
# 11 Rondônia             104.23  ...                           77.56
# 12 Acre                 104.21  ...                           69.33
# 13 Amazonas             107.67  ...                           65.70
# 14 Roraima              112.94  ...                           68.77
# 15 Pará                 109.26  ...                           71.96
# 16 Amapá                112.59  ...                           69.41
# 17 Tocantins            105.86  ...                           74.48
# 21 Maranhão             111.95  ...                           72.37
# 22 Piauí                101.81  ...                           68.87
# 23 Ceará                109.27  ...                           74.60
# 24 Rio Grande do Norte  102.79  ...                           70.79
# 25 Paraíba              105.55  ...                           71.96
# ...

# %% [markdown]
# Retirando os números que antecedem os nomes das Unidades da Federação:

# %%
dados_im_final.index = dados_im_final.index.str[3:] #retirar as três primeiras strings
dados_im_final.index
# Out:
# Index(['Rondônia', 'Acre', 'Amazonas', 'Roraima', 'Pará', 'Amapá', 'Tocantins',
#        'Maranhão', 'Piauí', 'Ceará', 'Rio Grande do Norte', 'Paraíba',
#        'Pernambuco', 'Alagoas', 'Sergipe', 'Bahia', 'Minas Gerais',
#        'Espírito Santo', 'Rio de Janeiro', 'São Paulo', 'Paraná',
#        'Santa Catarina', 'Rio Grande do Sul', 'Mato Grosso do Sul',
#        'Mato Grosso', 'Goiás', 'Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %% [markdown]
# <a name="results1"></a>
# ##**Análise dos dados**

# %% [markdown]
# ###**Análise da Cobertura Vacinal no Brasil, no período de 1994-2019**

# %% [markdown]
# Gráfico mostrando os valores de cobertura vacinal no Brasil, no período de 1994 a 2019:

# %%
plt.figure(figsize=(10,6))

ax = sns.lineplot(data=cobertura_aberto, x="ano", y="cobertura", color=BLUE1)

ax.set_title('Cobertura Vacinal no Brasil\n 1994 a 2019', loc = 'left', fontsize = 19, color = GRAY2, weight='bold')
ax.tick_params(color = 'darkgrey', bottom = 'off')
ax.spines['bottom'].set_color('darkgrey')
ax.spines['left'].set_color('darkgrey')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_ylabel('Cobertura Vacinal %',fontsize = 14, color = GRAY4,  weight='bold')
ax.set_xlabel('')
plt.xticks(fontsize=12, color = GRAY4, weight='bold')
plt.yticks(fontsize=12, color = GRAY4, weight='bold')

plt.ylim(0, 100)
plt.xticks(rotation=360)
plt.grid(linestyle="--")

plt.show()

# %% [markdown]
# Nesse gráfico a linha azul representa o que podemos esperar que seja a média dos valores. Isso é, de todos os valores, esse é o valor médio para todas as Unidades da Federação. Essa faixa azul mais clara é um intervalo de confiança criado estatisticamente. O plot agrega vários de Y para um mesmo valor de X. Então, ele mostra uma estimativa de tendência central, que no nesse caso é a média, e o intervalo de confiança para aquela estimativa.
#
# Como podemos observar, as coberturas vacinais estavam em torno de 40% no ano inicial (1994) e foram subindo gradativamente até 1999. **Entre  2000-2012 há uma estabilização e as médias das coberturas vacinais ficam próximas de 80%**. Após 2012 vemos um aumento na cobertura (com valores médios acima de 80%), porém, há uma **queda em 2016 para uma cobertura média de 52.64%**. Os valores voltam a subir tendo uma média de 72.65% em 2018. E a queda no último ano, é certamente pelo fato dos dados de 2019 estarem incompletos, já que a base de dados foi atualizada pela última vez em 04/09/2019, segundo informações disponíveis no TabNet.
#
# É interesse destacar que em 2015 o País teve a maior média de cobertura vacinal: 93.70%.
#
# De acordo com uma matéria da Fiocruz, **a curva de queda nas principais vacinas oferecidas gratuitamente à população começou em 2016** e repetiu-se nos dois anos seguintes, em descompasso com os anos anteriores. **Tal cenário faz com que o PNI (Programa Nacional de Imunizações) tenha tido, em 2017, as piores coberturas desde 2000 para as principais vacinas do calendário**.
#
# Esse tipo de informação é preocupante, pois **baixas coberturas** alcançadas para as principais vacinas do Calendário Nacional de Vacinação representam uma **ameaça real de retorno de doenças comuns no passado**, como o sarampo e a poliomielite (paralisia infantil).
#
# Inclusive, **em 2018 tivemos o retorno do Sarampo**, com o registro de 10.274 casos no País. O País enfrentou dois surtos da doença: no Amazonas e em Roraima. Além disso, casos isolados foram notificados em outros Estados. E nós, claramente, tivemos esses casos de sarampo no Brasil porque não tínhamos cobertura de vacinação adequada.
#
# A queda da cobertura vacinal pode estar relacionada com a hesitação à vacinação, definida como atraso na aceitação ou recusa das vacinas recomendadas, apesar da sua disponibilidade nos serviços de saúde. Um [estudo](https://www.revistas.usp.br/rsp/article/view/152007) apontou que os **principais motivos da hesitação à vacinação são falta de confiança quanto à eficácia/segurança da vacina e preocupações com eventos adversos**.

# %% [markdown]
# **Análise por Região:**

# %%
#Defininindo as regiões:

norte= ['Pará', 'Amazonas', 'Rondônia', 'Tocantins', 'Acre', 'Roraima','Amapá']
ano_norte = cobertura_aberto[cobertura_aberto['uf'].isin(norte)]

nordeste= ['Bahia', 'Pernambuco','Ceará', 'Maranhão', 'Rio Grande do Norte', 'Piauí', 'Paraíba','Alagoas', 'Sergipe']
ano_nordeste = cobertura_aberto[cobertura_aberto['uf'].isin(nordeste)]

sudeste = ['Minas Gerais', 'São Paulo', 'Rio de Janeiro', 'Espírito Santo']
ano_sudeste = cobertura_aberto[cobertura_aberto['uf'].isin(sudeste)]

sul = ['Paraná', 'Rio Grande do Sul', 'Santa Catarina']
ano_sul = cobertura_aberto[cobertura_aberto['uf'].isin(sul)]

centro_oeste= ['Goiás','Distrito Federal','Mato Grosso','Mato Grosso do Sul']
ano_centro_oeste = cobertura_aberto[cobertura_aberto['uf'].isin(centro_oeste)]

# %% [markdown]
# Gráfico mostrando os valores de cobertura vacinal por região do Brasil, no período de 1994 a 2019:

# %%
fig, axes = plt.subplots(2, 3, sharey = True, figsize = (18, 14))

fig.text(0.085, 0.95, '$\\bf{Cobertura\ Vacinal\ por\ Região\ do\ Brasil\ de\ 1994\ até\ 2019}$',
         fontsize = 20, color = GRAY3)

axes[1, 2].set_visible(False)


sns.lineplot(data=ano_norte, x="ano", y="cobertura", hue="uf", ax = axes[0, 0], palette = 'Paired')
axes[0, 0].set_title('Região Norte', loc = 'left', fontsize = 19, color = GRAY4, weight='bold')
axes[0, 0].tick_params(color=GRAY7)
axes[0, 0].spines['bottom'].set_color('darkgrey')
axes[0, 0].spines['left'].set_color('darkgrey')
axes[0, 0].spines['right'].set_visible(False)
axes[0, 0].spines['top'].set_visible(False)
axes[0, 0].tick_params(bottom='off')
axes[0, 0].set_xticklabels(ax.get_xticklabels(),rotation=30, color = GRAY4, weight='bold')
axes[0, 0].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[0, 0].set_ylabel('Cobertura Vacinal %',  fontsize = 14, color = GRAY4, weight='bold')
axes[0, 0].set_xlabel('')
axes[0, 0].set_ylim([0, 120])

sns.lineplot(data=ano_nordeste, x="ano", y="cobertura", hue="uf", ax = axes[0, 1],  palette = 'Paired')
axes[0, 1].set_title('Região Nordeste', loc = 'left', fontsize = 19, color = GRAY4, weight='bold')
axes[0, 1].spines['bottom'].set_color('darkgrey')
axes[0, 1].spines['left'].set_color('darkgrey')
axes[0, 1].spines['right'].set_visible(False)
axes[0, 1].spines['top'].set_visible(False)
axes[0, 1].tick_params(bottom='off')
axes[0, 1].set_xticklabels(ax.get_xticklabels(),rotation=30, color = GRAY4, weight='bold')
axes[0, 1].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[0, 1].set_ylabel('Cobertura Vacinal %',  fontsize = 14, color = GRAY4, weight='bold')
axes[0, 1].set_xlabel('')
axes[0, 1].set_ylim([0, 120])

sns.lineplot(data=ano_sudeste, x="ano", y="cobertura", hue="uf", ax = axes[0, 2],palette ='Paired')
axes[0, 2].set_title('Região Sudeste', loc = 'left', fontsize = 19, color = GRAY4, weight='bold')
axes[0, 2].spines['bottom'].set_color('darkgrey')
axes[0, 2].spines['left'].set_color('darkgrey')
axes[0, 2].spines['right'].set_visible(False)
axes[0, 2].spines['top'].set_visible(False)
axes[0, 2].tick_params(bottom='off')
axes[0, 2].set_xticklabels(ax.get_xticklabels(),rotation=30, color = GRAY4, weight='bold')
axes[0, 2].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[0, 2].set_ylabel('Cobertura Vacinal %',  fontsize = 14, color = GRAY4, weight='bold')
axes[0, 2].set_xlabel('')
axes[0, 2].set_ylim([0, 120])

sns.lineplot(data=ano_sul, x="ano", y="cobertura", hue="uf", ax = axes[1, 0], palette = 'Paired')
axes[1, 0].set_title('Região Sul', loc = 'left', fontsize = 19, color = GRAY4, weight='bold')
axes[1, 0].spines['bottom'].set_color('darkgrey')
axes[1, 0].spines['left'].set_color('darkgrey')
axes[1, 0].spines['right'].set_visible(False)
axes[1, 0].spines['top'].set_visible(False)
axes[1, 0].tick_params(bottom='off')
axes[1, 0].set_xticklabels(ax.get_xticklabels(),rotation=30, color = GRAY4, weight='bold')
axes[1, 0].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[1, 0].set_ylabel('Cobertura Vacinal %',  fontsize = 14, color = GRAY4, weight='bold')
axes[1, 0].set_xlabel('')
axes[1, 0].set_ylim([0, 120])

sns.lineplot(data=ano_centro_oeste, x="ano", y="cobertura", hue="uf", ax = axes[1, 1], palette = 'Paired')
axes[1, 1].set_title('Região Centro-Oeste', loc = 'left', fontsize = 19, color = GRAY4, weight='bold')
axes[1, 1].spines['bottom'].set_color('darkgrey')
axes[1, 1].spines['left'].set_color('darkgrey')
axes[1, 1].spines['left'].set_color(GRAY7)
axes[1, 1].spines['right'].set_visible(False)
axes[1, 1].spines['top'].set_visible(False)
axes[1, 1].tick_params(bottom='off')
axes[1, 1].set_xticklabels(ax.get_xticklabels(),rotation=30, color = GRAY4, weight='bold')
axes[1, 1].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[1, 1].set_ylabel('Cobertura Vacinal %',  fontsize = 14, color = GRAY4,  weight='bold')
axes[1, 1].set_xlabel('')
axes[1, 1].set_ylim([0, 120])

axes[1, 0].set_position([0.24, 0.125, 0.228, 0.343])
axes[1, 1].set_position([0.55, 0.125, 0.228, 0.343])

#plt.savefig('3.jpg')

plt.show()

# %% [markdown]
# Ao realizar a mesma análise, porém separando os gráficos por regiões e com os valores reais ao invés de usarmos as médias, vemos que **todas as regiões apresentam a mesma tendência**, com uma **queda brusca das coberturas vacinais em 2016**.
#
# Estados que atingiram 100% de cobertura em pelo menos algum período da análise (1994-2019):
#
# Região Norte: Rondônia, Roraima e Amapá
#
# Região Nordeste: Maranhão e Pernambuco
#
# Região Sudeste: Todos os Estados
#
# Região Sul: Santa Catarina
#
# Região Centro-Oeste: Mato Grosso e Mato Grosso do Sul

# %% [markdown]
# ###**Análise da Cobertura da Vacinação nas Unidades da Federação por Imunobiológico**

# %% [markdown]
# ####**Quais são os Imunobiológicos com Maiores Diferenças nas Coberturas Vacinais por Unidade da Federação?**

# %% [markdown]
# Gráfico mostrando os imunobiológicos com maiores diferenças nas coberturas vacinais por Unidade da Federação, no período de 1994 a 2019:

# %%
fig, axes = plt.subplots(2, 2, sharey = True, figsize = (28, 12))
fig.subplots_adjust(left=0.20, right=0.73, top=0.91, bottom=0.27)

axes[1, 1].set_visible(True)

sns.barplot(data=dados_im_final, x=dados_im_final.index, y="Febre Amarela", ax = axes[0, 0], palette = "rocket_r", hue="Febre Amarela", dodge=False)
axes[0, 0].set_title('Febre Amarela', loc = 'left', fontsize = 16, color = GRAY4, weight='bold')
axes[0, 0].set_xticklabels(ax.get_xticklabels(),rotation=90, color = GRAY4, weight='bold')
axes[0, 0].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[0, 0].set_ylabel('Cobertura Vacinal %',  fontsize = 14, color = GRAY4,  weight='bold')
axes[0, 0].set_xlabel('')
axes[0, 0].legend('')
axes[0, 0].set_ylim([0, 100])
axes[0, 0].spines['bottom'].set_color('darkgrey')
axes[0, 0].spines['left'].set_color('darkgrey')
axes[0, 0].spines['right'].set_visible(False)
axes[0, 0].spines['top'].set_visible(False)


sns.barplot(data=dados_im_final, x=dados_im_final.index, y="Sarampo", ax = axes[0, 1], palette = "rocket_r", hue="Sarampo", dodge=False)
axes[0, 1].set_title('Sarampo', loc = 'left', fontsize = 16, color = GRAY4, weight='bold')
axes[0, 1].set_xticklabels(ax.get_xticklabels(),rotation=90, color = GRAY4, weight='bold')
axes[0, 1].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[0, 1].set_ylabel('Cobertura Vacinal %', fontsize = 14, color = GRAY4,  weight='bold')
axes[0, 1].set_xlabel('')
axes[0, 1].legend('')
axes[0, 1].set_ylim([0, 100])
axes[0, 1].spines['bottom'].set_color('darkgrey')
axes[0, 1].spines['left'].set_color('darkgrey')
axes[0, 1].spines['right'].set_visible(False)
axes[0, 1].spines['top'].set_visible(False)

sns.barplot(data=dados_im_final, x=dados_im_final.index, y="Poliomielite 4 anos", ax = axes[1, 0], palette = "rocket_r", hue="Poliomielite 4 anos", dodge=False)
axes[1, 0].set_title('Poliomielite 4 anos', loc = 'left', fontsize = 16, color = GRAY4, weight='bold')
axes[1, 0].set_xticklabels(ax.get_xticklabels(),rotation=90, color = GRAY4, weight='bold')
axes[1, 0].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[1, 0].set_ylabel('Cobertura Vacinal %',fontsize = 14, color = GRAY4,  weight='bold')
axes[1, 0].set_xlabel('')
axes[1, 0].legend('')
axes[1, 0].set_ylim([0, 100])
axes[1, 0].spines['bottom'].set_color('darkgrey')
axes[1, 0].spines['left'].set_color('darkgrey')
axes[1, 0].spines['right'].set_visible(False)
axes[1, 0].spines['top'].set_visible(False)

sns.barplot(data=dados_im_final, x=dados_im_final.index, y="Tetra Viral(SRC+VZ)", ax = axes[1, 1], palette = "rocket_r", hue="Tetra Viral(SRC+VZ)", dodge=False)
axes[1, 1].set_title('Tetra Viral(SRC+VZ)', loc = 'left', fontsize = 16, color = GRAY4, weight='bold')
axes[1, 1].set_xticklabels(ax.get_xticklabels(),rotation=90, color = GRAY4, weight='bold')
axes[1, 1].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[1, 1].set_ylabel('Cobertura Vacinal %',fontsize = 14, color = GRAY4,  weight='bold')
axes[1, 1].set_xlabel('')
axes[1, 1].legend('')
axes[1, 1].set_ylim([0, 100])
axes[1, 1].spines['bottom'].set_color('darkgrey')
axes[1, 1].spines['left'].set_color('darkgrey')
axes[1, 1].spines['right'].set_visible(False)
axes[1, 1].spines['top'].set_visible(False)



axes[1, 0].set_position([0.20, 0.05, 0.228, 0.343])
axes[1, 1].set_position([0.49, 0.05, 0.228, 0.343])


#plt.savefig('1.jpg')

plt.show()

# %% [markdown]
# Em relação à **Febre Amarela**, a **cobertura vacinal só é alta na Região Norte, na Região Nordeste no Maranhão, Bahia e na Região Centro-Oeste, em todos os Estados exceto no Distrito Federal**.
#
# Segundo o [Guia para  Profissionais  de Saúde](https://portalarquivos2.saude.gov.br/images/pdf/2018/janeiro/18/Guia-febre-amarela-2018.pdf) , desenvolvido pelo Ministério da Saúde, a vacina contra febre amarela é recomendada apenas para Residentes ou viajantes para as áreas com recomendação de vacinação. As áreas recomendadas são:
#
# - Todos os estados das regiões Norte e Centro-Oeste;
#
# - Minas Gerais, Espírito Santo e Maranhão;
#
# - Alguns municípios dos estados do Piauí, Bahia, São Paulo, Rio de Janeiro, Paraná, Santa Catarina e Rio Grande do Sul); os estados de Sergipe (município de Canindé de São Francisco) e de Alagoas (município de Delmiro Gouveia).
#
# Considerando essas recomendações, por serem áreas endêmicas, **a cobertura não é ideal no Espírito Santo e no Distrito Federal, onde as coberturas não chegam a 50%.**
#
# No caso do **Sarampo**, é extremamente preocupante o fato do **Distrito Federal**, que teve **cobertura vacinal de 5.74%**.
# Em 2020, [a cobertura vacinal em adultos ficou em 9%](https://g1.globo.com/df/distrito-federal/noticia/2021/01/15/sarampo-no-df-cobertura-vacinal-em-adultos-ficou-em-9percent-em-2020-meta-era-imunizar-95percent.ghtml), mas a meta era imunizar 95% dos adultos. A Campanha chegou a ser prorrogada duas vezes e, segundo a Secretaria de Saúde, esse resultado pode ter sido influenciado pela pandemia de SARS-CoV-2.
#
# **São Paulo, Ceará e Pernambuco são os Estados com maior cobertura vacinal contra o sarampo, chegando perto de 100%.**
#
# Temida no passado pelas sequelas permanentes causadas em crianças, como a paralisia, a poliomielite foi eliminada do país depois do último caso, em 1989, graças às ações de vacinação nos postos de saúde e nas campanhas nacionais.
#
# Porém, como podemos ver no gráfico no caso da **Vacinação contra Poliomelite (4 anos)**, as **coberturas vacinais são péssimas em grande parte do País**, com **cobertura mínima de 27.98% e cobertura média de 60.37%**. Os **piores cenários são vistos em Amapá, Pará, Maranhão, Acre, Bahia e Rio Grande do Norte, onde a vacinação não chega nem a 50% de cobertura.**
#
# A **Tetra Viral (SRC + VZ: contra sarampo, caxumba, rubéola e varicela) não alcançou ao menos 80% de cobertura vacinal em nenhuma das Unidades da Federação**. Os melhores valores de cobertura se concentram nas Regiões Sul e Centro-Oeste e na  Região Norte nos Estados: Rondônia, Roraima, Tocantins, Amazonas e Amapá.

# %% [markdown]
# ####**Quais são os Imunobiológicos com Maior Cobertura Vacinal nas Unidades da Federação?**

# %% [markdown]
# Gráfico mostrando os imunobiológicos com maiores coberturas vacinais por Unidade da Federação, no período de 1994 a 2019:

# %%
fig, axes = plt.subplots(2, 2, sharey = True, figsize = (28, 12))
fig.subplots_adjust(left=0.20, right=0.73, top=0.91, bottom=0.27)

axes[1, 1].set_visible(True)

sns.barplot(data=dados_im_final, x=dados_im_final.index, y="BCG", ax = axes[0, 0], palette = "rocket_r", hue="BCG", dodge=False)
axes[0, 0].set_title('BGC', loc = 'left', fontsize = 16, color = GRAY4, weight='bold')
axes[0, 0].set_xticklabels(ax.get_xticklabels(),rotation=90, color = GRAY4, weight='bold')
axes[0, 0].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[0, 0].set_ylabel('Cobertura Vacinal %',  fontsize = 14, color = GRAY4,  weight='bold')
axes[0, 0].set_xlabel('')
axes[0, 0].legend('')
axes[0, 0].set_ylim([0, 120])
axes[0, 0].spines['bottom'].set_color('darkgrey')
axes[0, 0].spines['left'].set_color('darkgrey')
axes[0, 0].spines['right'].set_visible(False)
axes[0, 0].spines['top'].set_visible(False)


sns.barplot(data=dados_im_final, x=dados_im_final.index, y="Poliomielite", ax = axes[0, 1], palette = "rocket_r", hue="Poliomielite", dodge=False)
axes[0, 1].set_title('Poliomielite', loc = 'left', fontsize = 16, color = GRAY4, weight='bold')
axes[0, 1].set_xticklabels(ax.get_xticklabels(),rotation=90, color = GRAY4, weight='bold')
axes[0, 1].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[0, 1].set_ylabel('Cobertura Vacinal %', fontsize = 14, color = GRAY4,  weight='bold')
axes[0, 1].set_xlabel('')
axes[0, 1].legend('')
axes[0, 1].set_ylim([0, 120])
axes[0, 1].spines['bottom'].set_color('darkgrey')
axes[0, 1].spines['left'].set_color('darkgrey')
axes[0, 1].spines['right'].set_visible(False)
axes[0, 1].spines['top'].set_visible(False)

sns.barplot(data=dados_im_final, x=dados_im_final.index, y="Tríplice Viral  D1", ax = axes[1, 0], palette = "rocket_r", hue="Tríplice Viral  D1", dodge=False)
axes[1, 0].set_title('Tríplice Viral D1', loc = 'left', fontsize = 16, color = GRAY4, weight='bold')
axes[1, 0].set_xticklabels(ax.get_xticklabels(),rotation=90, color = GRAY4, weight='bold')
axes[1, 0].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[1, 0].set_ylabel('Cobertura Vacinal %',fontsize = 14, color = GRAY4,  weight='bold')
axes[1, 0].set_xlabel('')
axes[1, 0].legend('')
axes[1, 0].set_ylim([0, 120])
axes[1, 0].spines['bottom'].set_color('darkgrey')
axes[1, 0].spines['left'].set_color('darkgrey')
axes[1, 0].spines['right'].set_visible(False)
axes[1, 0].spines['top'].set_visible(False)

sns.barplot(data=dados_im_final, x=dados_im_final.index, y="Tríplice Viral  D2", ax = axes[1, 1], palette = "rocket_r", hue="Tríplice Viral  D2", dodge=False)
axes[1, 1].set_title('Tríplice Viral D2', loc = 'left', fontsize = 16, color = GRAY4, weight='bold')
axes[1, 1].set_xticklabels(ax.get_xticklabels(),rotation=90, color = GRAY4, weight='bold')
axes[1, 1].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[1, 1].set_ylabel('Cobertura Vacinal %',fontsize = 14, color = GRAY4,  weight='bold')
axes[1, 1].set_xlabel('')
axes[1, 1].legend('')
axes[1, 1].set_ylim([0, 120])
axes[1, 1].spines['bottom'].set_color('darkgrey')
axes[1, 1].spines['left'].set_color('darkgrey')
axes[1, 1].spines['right'].set_visible(False)
axes[1, 1].spines['top'].set_visible(False)



axes[1, 0].set_position([0.20, 0.05, 0.228, 0.343])
axes[1, 1].set_position([0.49, 0.05, 0.228, 0.343])


#plt.savefig('1.jpg')

plt.show()

# %% [markdown]
# A **vacina BCG**, que previne a tuberculose, apresenta a maior cobertura vacinal, que é ótima em todas as Unidades da Federação.
# Dados apresentados pelo [Ministério da Saúde](https://agenciabrasil.ebc.com.br/saude/noticia/2019-09/bcg-e-unica-vacina-atingir-meta-de-imunizacao-desde-2017)  mostram que a BCG **foi a única vacina a alcançar a cobertura vacinal pretendida nos anos de 2017 e 2018**.
#
# Em segundo lugar temos a **vacina contra poliomielite**, **porém a cobertura não chega a 100% em todos os Estados**. A maioria dos Estados da Região Norte (exceto Tocantins) não atinge os 100% de cobertura e alguns Estados do Nordeste se encontram em uma situação similar: Maranhão, Piauí, Ceará, Alagoas e Bahia.
#
# Enquanto isso, a vacina **Tríplice viral apresenta ótima cobertura na primeira dose, mas quando olhamos a segunda dose vemos que o cenário muda completamente**, principalmente na região Norte, onde a melhor cobertura é em Rondônia com 82.36%. No Acre, por exemplo, a cobertura cai para 54.31%.
#
# A vacina Tríplice viral previne o sarampo, a caxumba e a rubéola e é ofertada no calendário desde 1995. [Porém, em 2017, a cobertura da primeira dose ficou abaixo da meta de 95%, enquanto a da segunda ficou em 74,9%](https://portal.fiocruz.br/noticia/revista-radis-aborda-queda-da-cobertura-vacinal-no-brasil)
#
# Podemos associar a queda da vacinação da tríplice viral ao **movimentos antivacina**, que ganharam força depois que o médico cirurgião Andrew Wakefield publicou um trabalho insinuando que a vacina tríplice viral  estaria associada ao autismo. [Esse trabalho foi publicado na revista Lancet em 1998](https://www.thelancet.com/journals/lancet/article/PIIS0140-6736(97)11096-0/fulltext), que é uma respeitada revista da área médica.
#
# Contudo, estudos posteriores refutaram a conexão e mostraram que Wakefield tinha ações de uma empresa que propunha o uso de outra vacina. O artigo foi retratado e sua licença médica foi cassada, mas o estrago estava feito e ressurgiram surtos de sarampo na Europa.
#
# [Fonte: Revista FAPESP](https://revistapesquisa.fapesp.br/resistencia-a-ciencia/)

# %% [markdown]
# #**Parte II: Vacinação contra HPV**
# #### **Verificar se houve aumento na aplicação de doses após o período que a vacina foi incluída no calendário de vacinação;**
# #### **Comparar a aplicação de doses nos sexos feminino e masculino e verificar se houve aumento de adesão no sexo masculino ao longo do tempo;**
# #### **Analisar a proporcionalidade da vacinação de acordo com o número de habitantes e verificar se há consistência nessas proporções nas Unidades da Federação;**
# #### **Analisar o número de doses aplicadas por faixa etária**
#
# > **Você pode acessar todos os resultados desse tema [aqui](#results2).**

# %% [markdown]
# <a name="imp2"></a>
# ##**Importando os dados**
# Os dados estão disponíveis no [Github](https://github.com/vqrca/bootcamp_alura_projeto_2/blob/main/Dados).
#
# Para carregar a base de dados foi necessário mudar o enconding dos dados para `encoding="ISO-8859-1"`. A indicação de separação do texto foi feita com `sep= ";"` e os decimais foram definidos `decimal =","`. Para retirar linhas desnecessárias foi necessário usar os comandos `skiprows` e `skipfooter`.

# %% [markdown]
# ###**Doses por ano**

# %%
doses_fem = pd.read_csv('https://raw.githubusercontent.com/vqrca/bootcamp_alura_projeto_2/main/Dados/HPV_doses_ano_feminino.csv', 
                        encoding='ISO-8859-1', skiprows=4, sep=';', skipfooter = 21, decimal =',')
doses_mas = pd.read_csv('https://raw.githubusercontent.com/vqrca/bootcamp_alura_projeto_2/main/Dados/HPV_doses_ano_masculino.csv', 
                        encoding='ISO-8859-1', skiprows=5, sep=';', skipfooter = 21, decimal =',')

# %% [markdown]
# ###**Doses por idade**

# %%
idade_fem = pd.read_csv('https://raw.githubusercontent.com/vqrca/bootcamp_alura_projeto_2/main/Dados/HPV_doses_faixa_etaria_feminino.csv', 
                        encoding='ISO-8859-1', skiprows=4, sep=';', skipfooter = 21, decimal =',')
idade_mas = pd.read_csv('https://raw.githubusercontent.com/vqrca/bootcamp_alura_projeto_2/main/Dados/HPV_doses_faixa_etaria_masculino.csv', 
                        encoding='ISO-8859-1', skiprows=5, sep=';', skipfooter = 21, decimal =',')

# %% [markdown]
# <a name="exp2"></a>
# ## **Análise exploratória dos dados**

# %% [markdown]
# ###**Doses por ano**

# %% [markdown]
# ####**Feminino**

# %%
doses_fem
# Out:
#       Unidade da Federação 2009     2012  ...    2018    2019    Total
# 0              11 Rondônia    -    52801  ...   23065   11208   260568
# 1                  12 Acre    -    26621  ...    9734    4136   142940
# 2              13 Amazonas    -   129715  ...   82459   53876   600233
# 3               14 Roraima    -    17024  ...   16312    5371   113575
# 4                  15 Pará    -   233524  ...   95233   57599  1188080
# 5                 16 Amapá    -    24588  ...   11688    6243   145468
# 6             17 Tocantins    -    47167  ...   18486   11741   245973
# 7              21 Maranhão    -   210940  ...   97664   51897  1183330
# 8                 22 Piauí   51    95832  ...   34820   21128   452176
# 9                 23 Ceará    -   241647  ...  127599   58143  1540648
# 10  24 Rio Grande do Norte    -    90013  ...   35243   16243   426703
# 11              25 Paraíba    -   103742  ...   54017   30937   583925
# ...

# %%
doses_fem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unidade da Federação  27 non-null     object
#  1   2009                  27 non-null     object
#  2   2012                  27 non-null     int64
#  3   2013                  27 non-null     object
#  4   2014                  27 non-null     int64
#  5   2015                  27 non-null     int64
#  6   2016                  27 non-null     int64
#  7   2017                  27 non-null     int64
#  8   2018                  27 non-null     int64
#  9   2019                  27 non-null     int64
#  10  Total                 27 non-null     int64
# dtypes: int64(8), object(3)
# memory usage: 2.4+ KB

# %% [markdown]
# Neste DataFrame temos uma linha para cada Unidade da Federação e colunas referentes aos anos 2009-2019.
# No final há uma coluna denominada 'Total'. Nas colunas 2009 e 2013 os dados com tipo *object*, pois há valores nulos marcados por '-'.

# %% [markdown]
# ####**Masculino**

# %%
doses_mas
# Out:
#       Unidade da Federação  2013  2014  2015  ...    2017    2018    2019   Total
# 0              11 Rondônia     -     4    21  ...   20343   12672    5323   38529
# 1                  12 Acre     -     6    93  ...   11919    4628    1695   18348
# 2              13 Amazonas     -    77   722  ...   67656   44035   25404  137960
# 3               14 Roraima     -    28    15  ...    9156    7220    2465   18910
# 4                  15 Pará     -  3111   256  ...   97011   47272   27008  174749
# 5                 16 Amapá     -    11    23  ...   10974    5496    2754   19288
# 6             17 Tocantins     -   305    26  ...   29395    9606    6061   45407
# 7              21 Maranhão     -   269   499  ...  102700   52071   24466  180570
# 8                 22 Piauí     -   138  1205  ...   42501   18873   10433   73208
# 9                 23 Ceará     -   975   473  ...  150764   55588   27283  235290
# ...

# %%
doses_mas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unidade da Federação  27 non-null     object
#  1   2013                  27 non-null     object
#  2   2014                  27 non-null     int64
#  3   2015                  27 non-null     int64
#  4   2016                  27 non-null     int64
#  5   2017                  27 non-null     int64
#  6   2018                  27 non-null     int64
#  7   2019                  27 non-null     int64
#  8   Total                 27 non-null     int64
# dtypes: int64(7), object(2)
# memory usage: 2.0+ KB

# %% [markdown]
# Neste DataFrame temos uma linha para cada Unidade da Federação e colunas referentes aos anos 2013-2019. No final há uma coluna denominada 'Total'. Na coluna 2013 os dados estão como *object*, pois há valores nulos marcados por '-'.

# %% [markdown]
# ###**Doses por idade**

# %% [markdown]
# ####**Feminino**

# %%
idade_fem.head()
# Out:
#   Unidade da Federação  Menor de 1 ano  ...  27 e mais    Total
# 0          11 Rondônia           52801  ...        552   260568
# 1              12 Acre           26621  ...        193   142940
# 2          13 Amazonas          129715  ...        555   600233
# 3           14 Roraima           17024  ...        175   113575
# 4              15 Pará          233524  ...       1957  1188080
#
# [5 rows x 16 columns]

# %%
idade_fem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unidade da Federação  27 non-null     object
#  1   Menor de 1 ano        27 non-null     int64
#  2   9 anos                27 non-null     int64
#  3   10 anos               27 non-null     int64
#  4   11 anos               27 non-null     int64
#  5   12 anos               27 non-null     int64
#  6   13 anos               27 non-null     int64
#  7   14 anos               27 non-null     int64
#  8   15 anos               27 non-null     int64
#  9   16 anos               27 non-null     int64
#  10  17 anos               27 non-null     int64
#  11  18 anos               27 non-null     int64
#  12  19 anos               27 non-null     int64
#  13  20 a 26 anos          27 non-null     int64
#  14  27 e mais             27 non-null     int64
# ...

# %% [markdown]
# Neste DataFrame temos uma linha para cada Unidade da Federação e colunas com as idades. No final há uma coluna denominada 'Total'.

# %% [markdown]
# ####**Masculino**

# %%
idade_mas.head()
# Out:
#   Unidade da Federação  9 anos  10 anos  ...  20 a 26 anos  27 e mais   Total
# 0          11 Rondônia     441      885  ...           160        109   38529
# 1              12 Acre     363      602  ...            21         81   18348
# 2          13 Amazonas    1524     4627  ...           350         91  137960
# 3           14 Roraima     175      288  ...           111         26   18910
# 4              15 Pará    2421     4606  ...           505        614  174749
#
# [5 rows x 15 columns]

# %%
idade_mas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unidade da Federação  27 non-null     object
#  1   9 anos                27 non-null     int64
#  2   10 anos               27 non-null     int64
#  3   11 anos               27 non-null     int64
#  4   12 anos               27 non-null     int64
#  5   13 anos               27 non-null     int64
#  6   14 anos               27 non-null     int64
#  7   15 anos               27 non-null     int64
#  8   16 anos               27 non-null     int64
#  9   17 anos               27 non-null     int64
#  10  18 anos               27 non-null     int64
#  11  19 anos               27 non-null     int64
#  12  20 a 26 anos          27 non-null     int64
#  13  27 e mais             27 non-null     int64
#  14  Total                 27 non-null     int64
# ...

# %% [markdown]
# Neste DataFrame temos uma linha para cada Unidade da Federação e colunas com as idades. No final há uma coluna denominada 'Total'.

# %% [markdown]
#  <a name="trat2"></a>
# ##**Tratamento das bases de dados**

# %% [markdown]
# ###**Doses por ano**

# %% [markdown]
# ####**Feminino**

# %% [markdown]
# Os dados anteriores ao ano que a campanha de vacinação contra HPV começou e a coluna 'Total' foram eliminados:

# %%
doses_feminino = doses_fem.drop('2009', axis=1)
doses_feminino = doses_feminino.drop('2012', axis=1)
doses_feminino = doses_feminino.drop('2013', axis=1)
doses_feminino = doses_feminino.drop('Total', axis=1)
doses_feminino.head()
# Out:
#   Unidade da Federação    2014    2015    2016    2017   2018   2019
# 0          11 Rondônia   66170   55550   24321   27408  23065  11208
# 1              12 Acre   38741   35764   11165   16779   9734   4136
# 2          13 Amazonas   75641  112460   57718   87824  82459  53876
# 3           14 Roraima   27665   25118    8790   13295  16312   5371
# 4              15 Pará  348689  197478  111792  143738  95233  57599

# %% [markdown]
# Definindo 'Unidade da Federação' como index:

# %%
doses_feminino = doses_feminino.set_index('Unidade da Federação')
doses_feminino.head()
# Out:
#                         2014    2015    2016    2017   2018   2019
# Unidade da Federação
# 11 Rondônia            66170   55550   24321   27408  23065  11208
# 12 Acre                38741   35764   11165   16779   9734   4136
# 13 Amazonas            75641  112460   57718   87824  82459  53876
# 14 Roraima             27665   25118    8790   13295  16312   5371
# 15 Pará               348689  197478  111792  143738  95233  57599

# %% [markdown]
# Retirando os números que antecedem os nomes das Unidades da Federação:

# %%
doses_feminino.index = doses_feminino.index.str[3:] #retirar as três primeiras strings
doses_feminino.index
# Out:
# Index(['Rondônia', 'Acre', 'Amazonas', 'Roraima', 'Pará', 'Amapá', 'Tocantins',
#        'Maranhão', 'Piauí', 'Ceará', 'Rio Grande do Norte', 'Paraíba',
#        'Pernambuco', 'Alagoas', 'Sergipe', 'Bahia', 'Minas Gerais',
#        'Espírito Santo', 'Rio de Janeiro', 'São Paulo', 'Paraná',
#        'Santa Catarina', 'Rio Grande do Sul', 'Mato Grosso do Sul',
#        'Mato Grosso', 'Goiás', 'Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %% [markdown]
# ####**Masculino**

# %% [markdown]
# Os dados anteriores ao ano que a campanha de vacinação contra HPV começou e a coluna 'Total' foram eliminados:

# %%
doses_masculino = doses_mas.drop('2013', axis=1)
doses_masculino = doses_masculino.drop('Total', axis=1)
doses_masculino.head()
# Out:
#   Unidade da Federação  2014  2015  2016   2017   2018   2019
# 0          11 Rondônia     4    21   166  20343  12672   5323
# 1              12 Acre     6    93     7  11919   4628   1695
# 2          13 Amazonas    77   722    66  67656  44035  25404
# 3           14 Roraima    28    15    26   9156   7220   2465
# 4              15 Pará  3111   256    91  97011  47272  27008

# %% [markdown]
#
#
# Definindo 'Unidade da Federação' como index:

# %%
doses_masculino = doses_masculino.set_index('Unidade da Federação')
doses_masculino.head()
# Out:
#                       2014  2015  2016   2017   2018   2019
# Unidade da Federação
# 11 Rondônia              4    21   166  20343  12672   5323
# 12 Acre                  6    93     7  11919   4628   1695
# 13 Amazonas             77   722    66  67656  44035  25404
# 14 Roraima              28    15    26   9156   7220   2465
# 15 Pará               3111   256    91  97011  47272  27008

# %% [markdown]
# Retirando os números que antecedem os nomes das Unidades da Federação:

# %%
doses_masculino.index = doses_masculino.index.str[3:] #retirar as três primeiras strings
doses_masculino.index
# Out:
# Index(['Rondônia', 'Acre', 'Amazonas', 'Roraima', 'Pará', 'Amapá', 'Tocantins',
#        'Maranhão', 'Piauí', 'Ceará', 'Rio Grande do Norte', 'Paraíba',
#        'Pernambuco', 'Alagoas', 'Sergipe', 'Bahia', 'Minas Gerais',
#        'Espírito Santo', 'Rio de Janeiro', 'São Paulo', 'Paraná',
#        'Santa Catarina', 'Rio Grande do Sul', 'Mato Grosso do Sul',
#        'Mato Grosso', 'Goiás', 'Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %% [markdown]
# ###**Doses por idade**

# %% [markdown]
# ####**Feminino**

# %% [markdown]
# A coluna *Menor de 1 ano* foi retirada, pois a vacina contra HPV só é realizada a partir dos 9 anos de idade e, provavelmente, eles dados foram colocados por engano nesse dataset, pois a soma total (incluindo todas as Unidades da Federação) de *Menor de 1 ano* é exatamente o valor de vacinações antes da campanha de vacinação começar. Além disso, a coluna 'Total' foi retirada:

# %%
idade_feminino = idade_fem.drop('Menor de 1 ano', axis=1)
idade_feminino = idade_feminino.drop('Total', axis=1)
idade_feminino.head()
# Out:
#   Unidade da Federação  9 anos  10 anos  ...  19 anos  20 a 26 anos  27 e mais
# 0          11 Rondônia   48014    36853  ...      339          2171        552
# 1              12 Acre   26441    21335  ...       18            98        193
# 2          13 Amazonas  148858   105561  ...      283          1512        555
# 3           14 Roraima   23026    16559  ...       70           199        175
# 4              15 Pará  211948   160921  ...      597          4317       1957
#
# [5 rows x 14 columns]

# %% [markdown]
# Retirando os números que antecedem os nomes das Unidades da Federação:

# %%
idade_feminino ['Unidade da Federação'] = idade_feminino ['Unidade da Federação'].apply(lambda x: x[3:])
idade_feminino.head()
# Out:
#   Unidade da Federação  9 anos  10 anos  ...  19 anos  20 a 26 anos  27 e mais
# 0             Rondônia   48014    36853  ...      339          2171        552
# 1                 Acre   26441    21335  ...       18            98        193
# 2             Amazonas  148858   105561  ...      283          1512        555
# 3              Roraima   23026    16559  ...       70           199        175
# 4                 Pará  211948   160921  ...      597          4317       1957
#
# [5 rows x 14 columns]

# %%
idade_feminino = idade_feminino.set_index('Unidade da Federação')
idade_feminino.head()
# Out:
#                       9 anos  10 anos  ...  20 a 26 anos  27 e mais
# Unidade da Federação                   ...
# Rondônia               48014    36853  ...          2171        552
# Acre                   26441    21335  ...            98        193
# Amazonas              148858   105561  ...          1512        555
# Roraima                23026    16559  ...           199        175
# Pará                  211948   160921  ...          4317       1957
#
# [5 rows x 13 columns]

# %% [markdown]
# ####**Masculino**

# %% [markdown]
# Retirando a coluna 'Total':

# %%
idade_masculino = idade_mas.drop('Total', axis=1)
idade_masculino.head()
# Out:
#   Unidade da Federação  9 anos  10 anos  ...  19 anos  20 a 26 anos  27 e mais
# 0          11 Rondônia     441      885  ...       42           160        109
# 1              12 Acre     363      602  ...        4            21         81
# 2          13 Amazonas    1524     4627  ...       96           350         91
# 3           14 Roraima     175      288  ...       12           111         26
# 4              15 Pará    2421     4606  ...       87           505        614
#
# [5 rows x 14 columns]

# %% [markdown]
# Retirando os números que antecedem os nomes das Unidades da Federação:

# %%
idade_masculino ['Unidade da Federação'] = idade_masculino['Unidade da Federação'].apply(lambda x: x[3:])
idade_masculino.head()
# Out:
#   Unidade da Federação  9 anos  10 anos  ...  19 anos  20 a 26 anos  27 e mais
# 0             Rondônia     441      885  ...       42           160        109
# 1                 Acre     363      602  ...        4            21         81
# 2             Amazonas    1524     4627  ...       96           350         91
# 3              Roraima     175      288  ...       12           111         26
# 4                 Pará    2421     4606  ...       87           505        614
#
# [5 rows x 14 columns]

# %% [markdown]
# Definindo 'Unidade da Federação' como index:

# %%
idade_masculino = idade_masculino.set_index('Unidade da Federação')
idade_masculino.head()
# Out:
#                       9 anos  10 anos  ...  20 a 26 anos  27 e mais
# Unidade da Federação                   ...
# Rondônia                 441      885  ...           160        109
# Acre                     363      602  ...            21         81
# Amazonas                1524     4627  ...           350         91
# Roraima                  175      288  ...           111         26
# Pará                    2421     4606  ...           505        614
#
# [5 rows x 13 columns]

# %% [markdown]
# Fazendo o processo de `melt`para ambos os DataFrames: feminino e masculino:

# %% [markdown]
# #### Feminino

# %%
idade_fem = idade_feminino.reset_index().melt(id_vars=['Unidade da Federação'])
idade_fem
# Out:
#     Unidade da Federação   variable   value
# 0               Rondônia     9 anos   48014
# 1                   Acre     9 anos   26441
# 2               Amazonas     9 anos  148858
# 3                Roraima     9 anos   23026
# 4                   Pará     9 anos  211948
# ..                   ...        ...     ...
# 346    Rio Grande do Sul  27 e mais    6874
# 347   Mato Grosso do Sul  27 e mais    1249
# 348          Mato Grosso  27 e mais    1555
# 349                Goiás  27 e mais    2668
# 350     Distrito Federal  27 e mais    6622
#
# [351 rows x 3 columns]

# %% [markdown]
# Definindo nome das colunas:

# %%
feminino_aberto = idade_fem
feminino_aberto.columns = ['uf', 'idade', 'doses']
feminino_aberto.head()
# Out:
#          uf   idade   doses
# 0  Rondônia  9 anos   48014
# 1      Acre  9 anos   26441
# 2  Amazonas  9 anos  148858
# 3   Roraima  9 anos   23026
# 4      Pará  9 anos  211948

# %% [markdown]
# #### Masculino

# %%
idade_mas = idade_masculino.reset_index().melt(id_vars=['Unidade da Federação'])
idade_mas
# Out:
#     Unidade da Federação   variable  value
# 0               Rondônia     9 anos    441
# 1                   Acre     9 anos    363
# 2               Amazonas     9 anos   1524
# 3                Roraima     9 anos    175
# 4                   Pará     9 anos   2421
# ..                   ...        ...    ...
# 346    Rio Grande do Sul  27 e mais   1352
# 347   Mato Grosso do Sul  27 e mais    207
# 348          Mato Grosso  27 e mais    327
# 349                Goiás  27 e mais    461
# 350     Distrito Federal  27 e mais    295
#
# [351 rows x 3 columns]

# %% [markdown]
# Definindo o nome das colunas:

# %%
masculino_aberto = idade_mas
masculino_aberto.columns = ['uf', 'idade', 'doses']
masculino_aberto.head()
# Out:
#          uf   idade  doses
# 0  Rondônia  9 anos    441
# 1      Acre  9 anos    363
# 2  Amazonas  9 anos   1524
# 3   Roraima  9 anos    175
# 4      Pará  9 anos   2421

# %% [markdown]
# <a name="results2"></a>
# ##**Análise dos dados**

# %% [markdown]
# ###**Houve Aumento na Aplicação de Doses Contra HPV Após 2014**?
#
# - **Comparação entre a aplicação de doses nos sexos feminino e masculino.**
#
# - **Houve aumento de adesão no sexo masculino ao longo tempo?**

# %% [markdown]
# Gráfico mostrando o número de doses aplicadas contra HPV no sexo feminino e masculino de 2014 a 2019, em todas as Unidades da Federação:

# %%
fig, axs = plt.subplots(1,2, figsize=(15,5))
doses_feminino.T.plot(kind='line', ax=axs[0], colormap='Paired', legend=None)
axs[0].yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
doses_masculino.T.plot(kind='line', ax=axs[1], colormap='Paired')
axs[0].set_title('HPV: Doses aplicadas - sexo feminino\n 2014-2019', weight='bold', fontsize=14, color = GRAY4)
axs[1].set_title('HPV: Doses aplicadas - sexo masculino\n 20214-2019', weight='bold', fontsize=14, color = GRAY4)
axs[0].tick_params(labelrotation=360, labelcolor = GRAY2, labelsize=12)
axs[1].tick_params(labelrotation=360, labelcolor = GRAY2, labelsize=12)

axs[0].set_xlabel('')
axs[1].set_xlabel('')
axs[0].tick_params(color=GRAY7)
axs[0].spines['bottom'].set_color('darkgrey')
axs[0].spines['left'].set_color('darkgrey')
axs[0].spines['right'].set_color('darkgrey')
axs[0].spines['top'].set_color('darkgrey')
axs[0].set_ylabel('Doses aplicadas',  fontsize = 12, color = GRAY4,  weight='bold')
axs[1].tick_params(color=GRAY7)
axs[1].spines['bottom'].set_color('darkgrey')
axs[1].spines['left'].set_color('darkgrey')
axs[1].spines['right'].set_color('darkgrey')
axs[1].spines['top'].set_color('darkgrey')
axs[1].set_ylabel('Doses aplicadas',  fontsize = 12, color = GRAY4,  weight='bold')

axs[0].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)
axs[1].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)

plt. legend(loc='upper center', bbox_to_anchor=(0.01, -0.20), fancybox=True, shadow=True, ncol=3)

plt.show()

# %% [markdown]
# Quando analisamos a vacinação contra o HPV é possível observar que no caso da vacinação no **sexo feminino os valores mais altos de doses aplicadas se concentram no ano inicial da campanha de vacinação (2014)** e as **doses aplicadas foram caindo ao longo do tempo, apresentando uma queda abrupta em 2016**. Em 2017 houve um pequeno aumento, mas as doses voltaram novamente a cair. Enquanto isso, **no caso das doses aplicadas no sexo masculino, as doses parecem ter começado a ser aplicadas somente em 2017, porém em 2018 as doses começam a declinar**.
#
# De fato, somente a partir de janeiro de 2007, o [Ministério da Saúde](https://www.saude.go.gov.br/noticias/3705-ministerio-da-saude-comeca-a-vacinar-meninos-contra-hpv-em-2017) passou a disponibilizar a vacina contra o HPV para a população masculina de 12 a 13 anos na rotina do Calendário Nacional de Vacinação do Sistema Único de Saúde (SUS).
#
# Segundo o ministério da saúde a faixa-etária seria ampliada, gradativamente, até 2020, quando seriam incluídos os meninos com 9 anos até 13 anos.
# A estratégia em incluir a vacinação no sexo masculino em 2017 teve como objetivo proteger contra os cânceres de pênis, garganta e ânus, doenças que estão diretamente relacionadas ao HPV.
#
# É importante nos atentarmos ao fato de que no **caso do sexo femino o valores máximos de doses atingem um máximo de 1.704.362 em São Paulo. Já no sexo masculino o valor máximo atingido é de apenas 508.998 em São Paulo.**
# Como nesse gráfico não é possível analisarmos de maneira adequada estado por estado, foi realizada uma análise em gráfico de barras para cada região do país.

# %% [markdown]
# #### **Análise por região:**

# %% [markdown]
# **Norte**

# %%
fig, axs = plt.subplots(1,2, figsize=(20,8))

doses_feminino.head(7).plot(kind='bar', ax=axs[0], colormap='Set2')
doses_masculino.head(7).plot(kind='bar', ax=axs[1], colormap='Set2')

axs[0].set_title('HPV: Doses aplicadas (sexo feminino)\n Região Norte', weight='bold', fontsize=14, color = GRAY4)
axs[1].set_title('HPV: Doses aplicadas (sexo masculino)\n Região Norte', weight='bold', fontsize=14, color = GRAY4)
axs[0].tick_params(labelrotation=360, labelcolor = GRAY2, labelsize=12)
axs[1].tick_params(labelrotation=360, labelcolor = GRAY2, labelsize=12)

axs[0].set_xlabel('')
axs[1].set_xlabel('')
axs[0].tick_params(color=GRAY7)
axs[0].spines['bottom'].set_color('darkgrey')
axs[0].spines['left'].set_color('darkgrey')
axs[0].spines['right'].set_color('darkgrey')
axs[0].spines['top'].set_color('darkgrey')
axs[0].set_ylabel('Doses aplicadas',  fontsize = 12, color = GRAY4,  weight='bold')
axs[1].tick_params(color=GRAY7)
axs[1].spines['bottom'].set_color('darkgrey')
axs[1].spines['left'].set_color('darkgrey')
axs[1].spines['right'].set_color('darkgrey')
axs[1].spines['top'].set_color('darkgrey')
axs[1].set_ylabel('Doses aplicadas',  fontsize = 12, color = GRAY4,  weight='bold')
axs[0].set_position([0.24, 0.125, 0.300, 0.443])
axs[1].set_position([0.65, 0.125, 0.300, 0.443])

axs[0].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)
axs[1].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)

plt.show()

# %% [markdown]
# Na região Norte: no sexo femino os períodos com mais doses aplicadas foram 2014 e 2015. Já no sexo masculino o ano com maior aplicação de doses foi 2017 e ao longo do tempo houve uma queda gradativa.

# %% [markdown]
# **Nordeste**

# %%
fig, axs = plt.subplots(1,2, figsize=(32,10))

doses_feminino[7:16].plot(kind='bar', ax=axs[0],colormap='Set2')
doses_masculino[7:16].plot(kind='bar', ax=axs[1],colormap='Set2')

axs[0].set_title('HPV: Doses aplicadas (sexo feminino)\n Região Nordeste', weight='bold', fontsize=14, color = GRAY4)

axs[1].set_title('HPV: Doses aplicadas (sexo masculino)\n Região Nordeste', weight='bold', fontsize=14, color = GRAY4)

axs[0].tick_params(labelrotation=360, labelcolor = GRAY2, labelsize=10)
axs[1].tick_params(labelrotation=360, labelcolor = GRAY2, labelsize=10)
axs[0].set_xlabel('')
axs[1].set_xlabel('')
axs[0].tick_params(color=GRAY7)
axs[0].spines['bottom'].set_color('darkgrey')
axs[0].spines['left'].set_color('darkgrey')
axs[0].spines['right'].set_color('darkgrey')
axs[0].spines['top'].set_color('darkgrey')
axs[0].set_ylabel('Doses aplicadas',  fontsize = 12, color = GRAY4,  weight='bold')
axs[1].tick_params(color=GRAY7)
axs[1].spines['bottom'].set_color('darkgrey')
axs[1].spines['left'].set_color('darkgrey')
axs[1].spines['right'].set_color('darkgrey')
axs[1].spines['top'].set_color('darkgrey')
axs[1].set_ylabel('Doses aplicadas',  fontsize = 12, color = GRAY4,  weight='bold')
axs[0].set_position([0.24, 0.125, 0.300, 0.443])
axs[1].set_position([0.60, 0.125, 0.300, 0.443])

axs[0].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)
axs[1].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)

plt.show()

# %% [markdown]
# Na região Nordeste: no sexo femino os períodos com mais doses aplicadas foram 2014 e 2015, e na maioria dos estados esses dois períodos estão com número de doses quase próximos. Já no sexo masculino o ano com maior aplicação de doses foi 2017 e ao longo do tempo houve uma queda gradativa.

# %% [markdown]
# **Sudeste**

# %%
fig, axs = plt.subplots(1,2, figsize=(20,8))

doses_feminino[16:20].plot(kind='bar', ax=axs[0], colormap='Set2')
doses_masculino[16:20].plot(kind='bar', ax=axs[1], colormap='Set2')

axs[0].set_title('HPV: Doses aplicadas (sexo feminino)\n Região Sudeste', weight='bold', fontsize=14, color = GRAY4)
axs[0].yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

axs[1].set_title('HPV: Doses aplicadas (sexo masculino)\n Região Sudeste', weight='bold', fontsize=14, color = GRAY4)

axs[0].tick_params(labelrotation=360, labelcolor = GRAY2, labelsize=12)
axs[1].tick_params(labelrotation=360, labelcolor = GRAY2, labelsize=12)

axs[0].set_xlabel('')
axs[1].set_xlabel('')
axs[0].tick_params(color=GRAY7)
axs[0].spines['bottom'].set_color('darkgrey')
axs[0].spines['left'].set_color('darkgrey')
axs[0].spines['right'].set_color('darkgrey')
axs[0].spines['top'].set_color('darkgrey')
axs[0].set_ylabel('Doses aplicadas',  fontsize = 12, color = GRAY4,  weight='bold')
axs[1].tick_params(color=GRAY7)
axs[1].spines['bottom'].set_color('darkgrey')
axs[1].spines['left'].set_color('darkgrey')
axs[1].spines['right'].set_color('darkgrey')
axs[1].spines['top'].set_color('darkgrey')
axs[1].set_ylabel('Doses aplicadas',  fontsize = 12, color = GRAY4,  weight='bold')
axs[0].set_position([0.24, 0.125, 0.300, 0.443])
axs[1].set_position([0.65, 0.125, 0.300, 0.443])


axs[0].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)
axs[1].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)


plt.show()

# %% [markdown]
# Na região Sudeste: no sexo femino os períodos com mais doses aplicadas foram 2014 e 2015. Já no sexo masculino o ano com maior aplicação de doses foi 2017 e ao longo do tempo houve uma queda gradativa.

# %% [markdown]
# **Sul**

# %%
fig, axs = plt.subplots(1,2, figsize=(20,8))

doses_feminino[20:23].plot(kind='bar', ax=axs[0], colormap='Set2')
doses_masculino[20:23].plot(kind='bar', ax=axs[1], colormap='Set2')


axs[0].set_title('HPV: Doses aplicadas (sexo feminino)\n Região Sul', weight='bold', fontsize=14, color = GRAY4)

axs[1].set_title('HPV: Doses aplicadas (sexo masculino)\n Região Sul', weight='bold', fontsize=14, color = GRAY4)

axs[0].tick_params(labelrotation=360, labelcolor = GRAY2, labelsize=12)
axs[1].tick_params(labelrotation=360, labelcolor = GRAY2, labelsize=12)
axs[0].set_xlabel('')
axs[1].set_xlabel('')
axs[0].tick_params(color=GRAY7)
axs[0].spines['bottom'].set_color('darkgrey')
axs[0].spines['left'].set_color('darkgrey')
axs[0].spines['right'].set_color('darkgrey')
axs[0].spines['top'].set_color('darkgrey')
axs[0].set_ylabel('Doses aplicadas',  fontsize = 12, color = GRAY4,  weight='bold')
axs[1].tick_params(color=GRAY7)
axs[1].spines['bottom'].set_color('darkgrey')
axs[1].spines['left'].set_color('darkgrey')
axs[1].spines['right'].set_color('darkgrey')
axs[1].spines['top'].set_color('darkgrey')
axs[1].set_ylabel('Doses aplicadas',  fontsize = 12, color = GRAY4,  weight='bold')
axs[0].set_position([0.24, 0.125, 0.300, 0.443])
axs[1].set_position([0.65, 0.125, 0.300, 0.443])

axs[0].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)
axs[1].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)

plt.show()

# %% [markdown]
# Na região Sul: no sexo femino os períodos com mais doses aplicadas foram 2014 e 2015. Já no sexo masculino o ano com maior aplicação de doses foi 2017 e ao longo do tempo houve uma queda gradativa, exceto no Paraná, onde em 2018 houve a maior aplicação de doses. Essa informação é relevantes, pois em todos os outros estados a aplicação de doses no sexo masculino sofreu uma queda abrupta.

# %% [markdown]
# **Centro-Oeste**

# %%
fig, axs = plt.subplots(1,2, figsize=(20,8))

doses_feminino[23:].plot(kind='bar', ax=axs[0],colormap='Set2')
doses_masculino[23:].plot(kind='bar', ax=axs[1],colormap='Set2')

axs[0].set_title('HPV: Doses aplicadas (sexo feminino)\n Região Centro-Oeste', weight='bold', fontsize=14, color = GRAY4)

axs[1].set_title('HPV: Doses aplicadas (sexo masculino)\n Região Centro-Oeste', weight='bold', fontsize=14, color = GRAY4)

axs[0].tick_params(labelrotation=360, labelcolor = GRAY2, labelsize=12)
axs[1].tick_params(labelrotation=360, labelcolor = GRAY2, labelsize=12)
axs[0].set_xlabel('')
axs[1].set_xlabel('')
axs[0].tick_params(color=GRAY7)
axs[0].spines['bottom'].set_color('darkgrey')
axs[0].spines['left'].set_color('darkgrey')
axs[0].spines['right'].set_color('darkgrey')
axs[0].spines['top'].set_color('darkgrey')
axs[0].set_ylabel('Doses aplicadas',  fontsize = 12, color = GRAY4,  weight='bold')
axs[1].tick_params(color=GRAY7)
axs[1].spines['bottom'].set_color('darkgrey')
axs[1].spines['left'].set_color('darkgrey')
axs[1].spines['right'].set_color('darkgrey')
axs[1].spines['top'].set_color('darkgrey')
axs[1].set_ylabel('Doses aplicadas',  fontsize = 12, color = GRAY4,  weight='bold')
axs[0].set_position([0.24, 0.125, 0.300, 0.443])
axs[1].set_position([0.65, 0.125, 0.300, 0.443])

plt.legend(bbox_to_anchor=(1.00, 1), loc='upper right')

axs[0].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)
axs[1].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)

plt.show()

# %% [markdown]
# Na região Centro-Oeste: no sexo femino os períodos com mais doses aplicadas foram 2014 e 2015 Já no sexo masculino o ano com maior aplicação de doses foi 2017 e ao longo do tempo houve uma queda gradativa.

# %% [markdown]
# ###**Proporção da vacinação contra HPV nas Unidades da Federação**

# %% [markdown]
# Abaixo segue a função criada para unir a estimativa populacional de cada Unidade da Federação aos dados que eu já tenho sobre número de doses aplicadas nos sexos feminino e masculino nos datasets `doses_feminino` e `doses_masculino`, respectivamente.
#
# Os dados de estimativa populacional foram obtidos no [Wikipédia](https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o), onde há uma lista da população das Unidades Federativas brasileiras, segundo estimativas de 1º de julho de 2020 do Instituto Brasileiro de Geografia e Estatística [(IBGE)](https://www.ibge.gov.br/estatisticas/sociais/populacao/9103-estimativas-de-populacao.html?=&t=resultados).
#
# A cobertura vacinal é o número de doses aplicadas (correspondente ao esquema completo de vacinação) de determinado imunobiológico dividido pela população alvo e multiplicado por 100, em uma área e tempo considerados.
# Este indicador corresponde ao percentual de pessoas vacinadas e potencialmente protegidas contra determinada doença.
#
# Como não temos um censo atual da população alvo, será feito somente um cálculo no número de doses/número de habitantes, só para saber se as doses aplicadas por habitantes é proporcional quando comparamos as Unidades da Federação.
#
# Como a estimativa de população disponível e utilizada nesse projeto é de 2020, vou trabalhar apenas nos anos mais recentes que temos nos datasets (2017 e 2018). Não vou considerar 2019, pois esses dados estão incompletos no Tabnet, já que a data de atualização dos dados é 04/09/2019.

# %%
def limpeza_tratamento(url, dados):

    #obtenção dos dados via URL: 
    html_content = requests.get(url).text
    soup = BeautifulSoup(html_content, "lxml")
    dados_tabela = pd.read_html(str(soup.find_all('table')[0]))
    populacao = pd.DataFrame(dados_tabela[0])
    
    populacao.drop(columns=['Posição', '% da pop. total', 'País comparável (habitantes)'], inplace=True) #Tirar colunas que não interessam
    populacao.rename(columns={'Unidade federativa':'uf', 'População':'populacao'}, inplace=True) #Renomear as colunas de interesse
    populacao.set_index('uf', inplace=True) #definir index
    populacao['populacao'] = populacao['populacao'].str.replace(' ', '').astype('int64') #remoção dos espaços em branco e conversão para números inteiros
    
    unida = populacao.join(dados) #união dos dados
    
    return populacao, unida

# %% [markdown]
# Função aplicada nos dados do dataset `doses_feminino`:

# %%
populacao, unida = limpeza_tratamento('https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o',doses_feminino)

# %%
feminino_pop = unida
feminino_pop.head()
# Out:
#                 populacao     2014     2015    2016    2017    2018    2019
# uf
# São Paulo        46289333  1704362  1257322  437785  606710  474032  319711
# Minas Gerais     21292666   871426   622006  215781  286715  237204  138250
# Rio de Janeiro   17366189   562511   393255  227728  312867  169177   56668
# Bahia            14930634   523561   351542  145004  224447  141145   86544
# Paraná           11516840   379463   283993  139102  143871  215335  109578

# %% [markdown]
# Função aplicada nos dados do dataset `doses_masculino`:

# %%
populacao, unida = limpeza_tratamento('https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o',doses_masculino)

# %%
masculino_pop = unida
masculino_pop.head()
# Out:
#                 populacao  2014  2015  2016    2017    2018    2019
# uf
# São Paulo        46289333  3727  4779  3556  508998  252811  159813
# Minas Gerais     21292666  1774   581   559  299028  142032   74395
# Rio de Janeiro   17366189  6443  2014  6207  200173   70470   27356
# Bahia            14930634  1549  1286   232  170846   73794   44259
# Paraná           11516840   544  1182   674  133477  138215   49236

# %% [markdown]
# 2019

# %%
#Função para formatar valores em milhões
@ticker.FuncFormatter
def million_formatter(x, pos):
      return "%.f Mi" % (x/1E6)

# %% [markdown]
# Gráficos mostrando o tamanho da população em relação ao número de doses aplicadas, para ambos os sexos, de 2014-2019.
#
# Lembrando, que os dados referentes a população são de 2020, então isso é só pra ter uma ideia se as doses aumentam conforme o tamanho da população, mas o adequado seria utilizar a estimativa de cada um dos anos.

# %%
fig, ax = plt.subplots(figsize=(5,5)) 
sns.scatterplot(data=masculino_pop, x='populacao', y='2019', color=RED1, s=80, label='Feminino')
sns.scatterplot(data=feminino_pop, x='populacao', y='2019', color=GREEN1, s=80, label='Masculino')
ax.xaxis.set_major_formatter(million_formatter)

plt.title('HPV: Doses aplicadas x População\n2019', fontsize=14, weight='bold', color=GRAY6)
plt.xlabel('Número de Habitantes', fontsize=12, weight='bold',color=GRAY6)
plt.ylabel('Doses aplicadas', fontsize=12, weight='bold', color=GRAY6)
ax.spines['bottom'].set_color('darkgrey')
ax.spines['left'].set_color('darkgrey')
ax.spines['right'].set_color('darkgrey')
ax.spines['top'].set_color('darkgrey')
ax.tick_params(axis='x',labelcolor = GRAY4, labelsize=12)
ax.tick_params(axis='y',labelcolor = GRAY4, labelsize=12)

legend = plt.legend()
plt.setp(legend.get_texts(), color=GRAY4)
plt.show()

# %% [markdown]
# 2018

# %%
fig, ax = plt.subplots(figsize=(5,5)) 
sns.scatterplot(data=masculino_pop, x='populacao', y='2018', color=RED1, s=80, label='Feminino')
sns.scatterplot(data=feminino_pop, x='populacao', y='2018', color=GREEN1, s=80, label='Masculino')
ax.xaxis.set_major_formatter(million_formatter)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('HPV: Doses aplicadas x População\n2018', fontsize=14, weight='bold', color=GRAY6)
plt.xlabel('Número de Habitantes', fontsize=12, weight='bold',color=GRAY6)
plt.ylabel('Doses aplicadas', fontsize=12, weight='bold', color=GRAY6)
ax.spines['bottom'].set_color('darkgrey')
ax.spines['left'].set_color('darkgrey')
ax.spines['right'].set_color('darkgrey')
ax.spines['top'].set_color('darkgrey')
ax.tick_params(axis='x',labelcolor = GRAY4, labelsize=12)
ax.tick_params(axis='y',labelcolor = GRAY4, labelsize=12)

legend = plt.legend()
plt.setp(legend.get_texts(), color=GRAY4)
plt.show()

# %% [markdown]
# 2017

# %%
fig, ax = plt.subplots(figsize=(5,5)) 
sns.scatterplot(data=masculino_pop, x='populacao', y='2017', color=RED1, s=80, label='Feminino')
sns.scatterplot(data=feminino_pop, x='populacao', y='2017', color=GREEN1, s=80, label='Masculino')
ax.xaxis.set_major_formatter(million_formatter)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('HPV: Doses aplicadas x População\n2017', fontsize=14, weight='bold', color=GRAY6)
plt.xlabel('Número de Habitantes', fontsize=12, weight='bold',color=GRAY6)
plt.ylabel('Doses aplicadas', fontsize=12, weight='bold', color=GRAY6)
ax.spines['bottom'].set_color('darkgrey')
ax.spines['left'].set_color('darkgrey')
ax.spines['right'].set_color('darkgrey')
ax.spines['top'].set_color('darkgrey')
ax.tick_params(axis='x',labelcolor = GRAY4, labelsize=12)
ax.tick_params(axis='y',labelcolor = GRAY4, labelsize=12)

legend = plt.legend()
plt.setp(legend.get_texts(), color=GRAY4)
plt.show()

# %% [markdown]
# 2016

# %%
fig, ax = plt.subplots(figsize=(5,5)) 
sns.scatterplot(data=masculino_pop, x='populacao', y='2016', color=RED1, s=80, label='Feminino')
sns.scatterplot(data=feminino_pop, x='populacao', y='2016', color=GREEN1, s=80, label='Masculino')
ax.xaxis.set_major_formatter(million_formatter)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('HPV: Doses aplicadas x População\n2016', fontsize=14, weight='bold', color=GRAY6)
plt.xlabel('Número de Habitantes', fontsize=12, weight='bold',color=GRAY6)
plt.ylabel('Doses aplicadas', fontsize=12, weight='bold', color=GRAY6)
ax.spines['bottom'].set_color('darkgrey')
ax.spines['left'].set_color('darkgrey')
ax.spines['right'].set_color('darkgrey')
ax.spines['top'].set_color('darkgrey')
ax.tick_params(axis='x',labelcolor = GRAY4, labelsize=12)
ax.tick_params(axis='y',labelcolor = GRAY4, labelsize=12)

legend = plt.legend()
plt.setp(legend.get_texts(), color=GRAY4)
plt.show()

# %% [markdown]
# 2015

# %%
fig, ax = plt.subplots(figsize=(5,5)) 
sns.scatterplot(data=masculino_pop, x='populacao', y='2015', color=RED1, s=80, label='Feminino')
sns.scatterplot(data=feminino_pop, x='populacao', y='2015', color=GREEN1, s=80, label='Masculino')
ax.xaxis.set_major_formatter(million_formatter)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('HPV: Doses aplicadas x População\n2015', fontsize=14, weight='bold', color=GRAY6)
plt.xlabel('Número de Habitantes', fontsize=12, weight='bold',color=GRAY6)
plt.ylabel('Doses aplicadas', fontsize=12, weight='bold', color=GRAY6)
ax.spines['bottom'].set_color('darkgrey')
ax.spines['left'].set_color('darkgrey')
ax.spines['right'].set_color('darkgrey')
ax.spines['top'].set_color('darkgrey')
ax.tick_params(axis='x',labelcolor = GRAY4, labelsize=12)
ax.tick_params(axis='y',labelcolor = GRAY4, labelsize=12)

legend = plt.legend()
plt.setp(legend.get_texts(), color=GRAY4)
plt.show()

# %% [markdown]
# 2014

# %%
fig, ax = plt.subplots(figsize=(5,5)) 
sns.scatterplot(data=masculino_pop, x='populacao', y='2014', color=RED1, s=80, label='Feminino')
sns.scatterplot(data=feminino_pop, x='populacao', y='2014', color=GREEN1, s=80, label='Masculino')
ax.xaxis.set_major_formatter(million_formatter)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('HPV: Doses aplicadas x População\n2014', fontsize=14, weight='bold', color=GRAY6)
plt.xlabel('Número de Habitantes', fontsize=12, weight='bold',color=GRAY6)
plt.ylabel('Doses aplicadas', fontsize=12, weight='bold', color=GRAY6)
ax.spines['bottom'].set_color('darkgrey')
ax.spines['left'].set_color('darkgrey')
ax.spines['right'].set_color('darkgrey')
ax.spines['top'].set_color('darkgrey')
ax.tick_params(axis='x',labelcolor = GRAY4, labelsize=12)
ax.tick_params(axis='y',labelcolor = GRAY4, labelsize=12)

legend = plt.legend()
plt.setp(legend.get_texts(), color=GRAY4)
plt.show()

# %% [markdown]
# Os gráficos acima indicam que **no período de 2014 a 2016 a vacinação estava ocorrendo de fato somente sexo feminino e que a vacinação era relacionada ao tamanho crescente da população**.
#
# Portanto, **quanto maior o número de habitantes, maior o número de doses aplicadas,** exceto em poucos pontos que ficariam fora de uma reta, caso fosse inserida uma reta nesses gráficos.
#
# **Em 2017, vemos que a vacinação estava ocorrendo nos sexos feminino e masculino, de forma proporcional à população**, porém nos **anos seguintes vemos que começa a ocorrer uma dispersão nos pontos, indicando que a aplicação de doses começou a não estar tão relacionada.**

# %% [markdown]
# ###**Estimando a proporção de doses aplicadas em todas as Unidades da Federação:**
# Para os anos 2017 e 2018

# %% [markdown]
# Feminino:

# %%
feminino_pop['proporcao 2017'] = (feminino_pop['2017'] /  feminino_pop['populacao'])
feminino_pop['porporcao 2018'] = (feminino_pop['2018'] /  feminino_pop['populacao'])
feminino_pop.head()
# Out:
#                 populacao     2014  ...  proporcao 2017  porporcao 2018
# uf                                  ...
# São Paulo        46289333  1704362  ...        0.013107        0.010241
# Minas Gerais     21292666   871426  ...        0.013465        0.011140
# Rio de Janeiro   17366189   562511  ...        0.018016        0.009742
# Bahia            14930634   523561  ...        0.015033        0.009453
# Paraná           11516840   379463  ...        0.012492        0.018697
#
# [5 rows x 9 columns]

# %% [markdown]
# Masculino:

# %%
masculino_pop['proporcao 2017'] = (masculino_pop['2017'] /  masculino_pop['populacao'])
masculino_pop['proporcao 2018'] = (masculino_pop['2018'] /  masculino_pop['populacao'])
masculino_pop.head()
# Out:
#                 populacao  2014  2015  ...    2019  proporcao 2017  proporcao 2018
# uf                                     ...
# São Paulo        46289333  3727  4779  ...  159813        0.010996        0.005462
# Minas Gerais     21292666  1774   581  ...   74395        0.014044        0.006670
# Rio de Janeiro   17366189  6443  2014  ...   27356        0.011527        0.004058
# Bahia            14930634  1549  1286  ...   44259        0.011443        0.004942
# Paraná           11516840   544  1182  ...   49236        0.011590        0.012001
#
# [5 rows x 9 columns]

# %% [markdown]
# Gráficos mostrando uma estimativa da proporção das doses aplicadas pela população nos anos, para cada Unidade da Federação, nos anos 2017 e 2018:

# %%
fig, axes = plt.subplots(2, 2, sharey = True, figsize = (28, 12))
fig.subplots_adjust(left=0.20, right=0.73, top=0.91, bottom=0.27)

axes[1, 1].set_visible(True)

sns.barplot(data=feminino_pop, x=feminino_pop.index, y='proporcao 2017', ax = axes[0, 0], palette = "Reds", hue="proporcao 2017", dodge=False)
axes[0, 0].set_title('HPV: Proporção das doses aplicadas em 2017 \n sexo feminino', loc = 'left', fontsize = 16, color = GRAY4, weight='bold')
axes[0, 0].set_xticklabels(ax.get_xticklabels(),rotation=90, fontsize = 12, color = GRAY4, weight='bold')
axes[0, 0].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[0, 0].set_ylabel('doses aplicadas/população',  fontsize = 12, color = GRAY4,  weight='bold')
axes[0, 0].set_xlabel('')
axes[0, 0].legend('')
axes[0, 0].yaxis.set_ticks_position('left')
axes[0, 0].set_ylim(0, 0.030)
axes[0, 0].spines['bottom'].set_color('darkgrey')
axes[0, 0].spines['left'].set_color('darkgrey')
axes[0, 0].spines['right'].set_visible(False)
axes[0, 0].spines['top'].set_visible(False)
axes[0, 0].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)

sns.barplot(data=masculino_pop, x=masculino_pop.index, y='proporcao 2017', ax = axes[0, 1], palette = "Greens", hue="proporcao 2017", dodge=False)
axes[0, 1].set_title('HPV: Proporção das doses aplicadas em 2017 \n sexo masculino', loc = 'left', fontsize = 16, color = GRAY4, weight='bold')
axes[0, 1].set_xticklabels(ax.get_xticklabels(),rotation=90, fontsize = 12, color = GRAY4, weight='bold')
axes[0, 1].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[0, 1].set_ylabel('doses aplicadas/população', fontsize = 12, color = GRAY4,  weight='bold')
axes[0, 1].set_xlabel('')
axes[0, 1].legend('')
axes[0, 1].yaxis.set_ticks_position('left')
axes[0, 0].set_ylim(0, 0.030)
axes[0, 1].spines['bottom'].set_color('darkgrey')
axes[0, 1].spines['left'].set_color('darkgrey')
axes[0, 1].spines['right'].set_visible(False)
axes[0, 1].spines['top'].set_visible(False)
axes[0, 1].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)

sns.barplot(data=feminino_pop, x=feminino_pop.index, y='porporcao 2018', ax = axes[1, 0], palette = "Reds", hue="porporcao 2018", dodge=False)
axes[1, 0].set_title('HPV: Proporção das doses aplicadas em 2018 \n sexo feminino', loc = 'left', fontsize = 16, color = GRAY4, weight='bold')
axes[1, 0].set_xticklabels(ax.get_xticklabels(),rotation=90, fontsize = 12, color = GRAY4, weight='bold')
axes[1, 0].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[1, 0].set_ylabel('doses aplicadas/população',fontsize = 12, color = GRAY4,  weight='bold')
axes[1, 0].set_xlabel('')
axes[1, 0].legend('')
axes[1, 0].yaxis.set_ticks_position('left')
axes[0, 0].set_ylim(0, 0.030)
axes[1, 0].spines['bottom'].set_color('darkgrey')
axes[1, 0].spines['left'].set_color('darkgrey')
axes[1, 0].spines['right'].set_visible(False)
axes[1, 0].spines['top'].set_visible(False)
axes[1, 0].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)

sns.barplot(data=masculino_pop, x=masculino_pop.index, y='proporcao 2018', ax = axes[1, 1], palette = "Greens", hue="proporcao 2018", dodge=False)
axes[1, 1].set_title('HPV: Proporção das doses aplicadas em 2018 \n sexo masculino', loc = 'left', fontsize = 16, color = GRAY4, weight='bold')
axes[1, 1].set_xticklabels(ax.get_xticklabels(),rotation=90,  fontsize = 12, color = GRAY4, weight='bold')
axes[1, 1].set_yticklabels(ax.get_yticklabels(), fontsize = 12, color = GRAY4, weight='bold')
axes[1, 1].set_ylabel('doses aplicadas/população',fontsize = 12, color = GRAY4,  weight='bold')
axes[1, 1].set_xlabel('')
axes[1, 1].legend('')
axes[0, 0].set_ylim(0, 0.030)
axes[1, 1].yaxis.set_ticks_position('left')
axes[1, 1].spines['bottom'].set_color('darkgrey')
axes[1, 1].spines['left'].set_color('darkgrey')
axes[1, 1].spines['right'].set_visible(False)
axes[1, 1].spines['top'].set_visible(False)
axes[1, 1].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)


axes[1, 0].set_position([0.20, 0.05, 0.228, 0.343])
axes[1, 1].set_position([0.49, 0.05, 0.228, 0.343])


#plt.savefig('1.jpg')

plt.show()

# %% [markdown]
# Ao analisar a proporcionalidade de doses aplicadas pela população, de cada Unidade da Federação, é possível observar que **em 2017 havia uma proporção mais homogênea.**
#
# **Em 2018 há uma série de discrepâncias, principalmente no sexo feminino, onde temos mais doses sendo aplicadas em Roraima, Amazonas e Paraná. Nos dados do sexo masculino há mais doses sendo aplicadas no Paraná, Roraima, Amazonas e Maranhão.**
#
# Essas **heterogeneidades na proporção** de doses aplicadas podem estar associadas a **políticas públicas estaduais distintas**, que **afetam a disponibilidade de vacinas para a população**.

# %% [markdown]
# ###**Análise do número de doses aplicadas por faixa etária**

# %% [markdown]
# Gráfico mostrando a comparação do número de doses aplicadas no sexos feminino e masculino, no período de 2014 a 2019:

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.set_theme(style="ticks")
feminino = sns.lineplot(data=feminino_aberto, x="idade", y="doses", color='#C3514E', label='Feminino')
masculino =sns.lineplot(data=masculino_aberto, x="idade", y="doses", color='#0C8040',label='Masculino')

ax.set_title('HPV: Doses aplicadas por idade no Brasil\n 2014-2019', loc='left', weight='bold', fontsize=18, color = GRAY4)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
ax.spines['bottom'].set_color('darkgrey')
ax.spines['left'].set_color('darkgrey')
ax.spines['right'].set_color('darkgrey')
ax.spines['top'].set_color('darkgrey')
ax.set_ylabel('Número de doses', fontsize=14, color = GRAY4, weight='bold')
ax.set_xlabel('')
ax.tick_params(axis='x',labelcolor = GRAY4, labelsize=14)
ax.tick_params(axis='y',labelcolor = GRAY4, labelsize=14)
ax.grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)
plt.ylim(0, 350000)
plt.xticks(rotation=70)
plt.grid(linestyle="--")
legend = plt.legend()
plt.setp(legend.get_texts(), color=GRAY4, fontsize=12, weight='bold')


plt.show()

# %% [markdown]
# As linhas do gráfico abaixo representam a média de doses aplicadas por idade em todas as Unidades da Federação. A faixa em volta das linhas é um intervalo de confiança criado estatisticamente.
#
# A análise de doses aplicadas por faixas etárias mostra que a **vacinação foi maior na faixa etária de 9 e 11 anos no sexo femino**, e que** abrangeu a faixa etária entre 9-14 anos**.
#
#
# No caso do **sexo masculino a vacinação abrangeu a faixa etária entre 11-14 anos, porém foi maior aos 11 e 12 anos de idade.**

# %% [markdown]
# Visualização dos gráficos separadamente:

# %%
fig, axs = plt.subplots(1,2, figsize=(20,5))

sns.lineplot(data=feminino_aberto, x="idade", y="doses", ax=axs[0], color=RED1)
sns.lineplot(data=masculino_aberto, x="idade", y="doses", ax=axs[1], color=GREEN1)

axs[0].set_title('HPV: Doses aplicadas - sexo feminino\n por idade',  loc='left', weight='bold', fontsize=18, color = GRAY4)
axs[1].set_title('HPV: Doses aplicadas - sexo masculino\n por idade',  loc='left', weight='bold', fontsize=18, color = GRAY4)
axs[0].yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
axs[1].yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
axs[0].tick_params(axis='x', rotation=70, labelcolor = GRAY4, labelsize=14)
axs[1].tick_params(axis='x', rotation=70, labelcolor = GRAY4, labelsize=14)
axs[0].set_xlabel('')
axs[1].set_xlabel('')
axs[0].spines['bottom'].set_color('darkgrey')
axs[0].spines['left'].set_color('darkgrey')
axs[0].spines['right'].set_color('darkgrey')
axs[0].spines['top'].set_color('darkgrey')
axs[0].set_ylabel('Doses aplicadas', fontsize=14, color = GRAY4, weight='bold')
axs[0].tick_params(axis='y',labelcolor = GRAY4, labelsize=14)
axs[1].tick_params(axis='y',labelcolor = GRAY4, labelsize=14)
axs[1].spines['bottom'].set_color('darkgrey')
axs[1].spines['left'].set_color('darkgrey')
axs[1].spines['right'].set_color('darkgrey')
axs[1].spines['top'].set_color('darkgrey')
axs[1].set_ylabel('Doses aplicadas', fontsize=14, color = GRAY4, weight='bold')
axs[0].set_position([0.24, 0.125, 0.300, 0.843])
axs[1].set_position([0.65, 0.125, 0.300, 0.843])
axs[0].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)
axs[1].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)

plt.show()

# %% [markdown]
# Visualização em barras:

# %%
fig, axs = plt.subplots(1,2, figsize=(20,5))

sns.barplot(data=feminino_aberto, x="idade", y="doses", ax=axs[0], color=RED2)
sns.barplot(data=masculino_aberto, x="idade", y="doses", ax=axs[1], color=GREEN2)

axs[0].set_title('HPV: Doses aplicadas - sexo feminino\n por idade', loc='left', weight='bold', fontsize=14, color = GRAY4)
axs[1].set_title('HPV: Doses aplicadas - sexo masculino\n por idade', loc='left', weight='bold', fontsize=14, color = GRAY4)
axs[0].yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
axs[1].yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
axs[0].tick_params(axis='x', rotation=70, labelcolor = GRAY4, labelsize=14)
axs[1].tick_params(axis='x', rotation=70, labelcolor = GRAY4, labelsize=14)
axs[0].set_xlabel('')
axs[1].set_xlabel('')
axs[0].spines['bottom'].set_color('darkgrey')
axs[0].spines['left'].set_color('darkgrey')
axs[0].spines['right'].set_color('darkgrey')
axs[0].spines['top'].set_color('darkgrey')
axs[0].set_ylabel('Doses aplicadas', fontsize=14, color = GRAY4, weight='bold')
axs[0].tick_params(axis='y',labelcolor = GRAY4, labelsize=14)
axs[1].tick_params(axis='y',labelcolor = GRAY4, labelsize=14)
axs[1].spines['bottom'].set_color('darkgrey')
axs[1].spines['left'].set_color('darkgrey')
axs[1].spines['right'].set_color('darkgrey')
axs[1].spines['top'].set_color('darkgrey')
axs[1].set_ylabel('Doses aplicadas', fontsize=14, color = GRAY4, weight='bold')
axs[0].set_position([0.24, 0.125, 0.300, 0.843])
axs[1].set_position([0.65, 0.125, 0.300, 0.843])
axs[0].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)
axs[1].grid(b=True, which='major', color=GRAY6, linestyle='--', alpha=0.3)

plt.show()

# %% [markdown]
# Segundo o [Informe técnico](https://portalarquivos2.saude.gov.br/images/pdf/2018/marco/14/Informe-T--cnico-HPV-MENINGITE.pdf)  a ampliação da oferta das vacinas contra HPV e a inclusão das populações-alvo no calendário de vacinação ocorreram de forma gradual. Começou por meninas de 11 a 13 anos de idade em 2014, foi ampliada para a faixa etária de nove a 11 anos em 2015 e foi expandida para meninas com 14 anos de idade em 2017.
#
# As **doses acima de 14 anos**, provavelmente, estão relacionadas ao fato da **vacina ter sido disponibilizada para as mulheres e homens até 26 anos de idade** vivendo com HIV/AIDS, transplantados de órgãos sólidos, de medula óssea e pacientes oncológicos.
#
# Conforme anunciado pelo [Ministério da Saúde](https://www.gov.br/saude/pt-br/assuntos/noticias/saude-amplia-vacinacao-contra-hpv-para-mulheres-imunossuprimidas-com-ate-45-anos), atualmente (em 2021), mulheres com imunossupressão, vivendo com HIV/Aids, transplantadas e portadoras de cânceres, com até 45 anos de idade podem tomar a vacina contra o HPV. Já que a imunossupressão é reconhecida como um dos principais fatores de risco para infecção pelo HPV e para o desenvolvimento de lesões tumorais e verrugas genitais.
#
#
# [Moro e colaboradores(2017)](http://www.periodicos.unc.br/index.php/sma/article/view/1528), mostraram que em 2014, 87% dos municípios brasileiros atingiram a meta preconizada na primeira dose, porém apenas 32% atingiram a meta da segunda dose. As explicações elencadas para a baixa cobertura foram dificuldade de acesso, falhas nos registros de doses de vacinas aplicadas, erros de digitação e imprecisões dos dados demográficos utilizados na estimação do número de indivíduos na faixa etária alvo [(Tobias et al., 2017)](https://periodicos.ufpe.br/revistas/revistaenfermagem/article/view/22841)

# %% [markdown]
# <a name="conc"></a>
# #**Conclusões**
#
# ## Parte I
# - Como podemos observar, as coberturas vacinais estavam em torno de 40% no ano inicial (1994) e foram subindo gradativamente até 1999. **Entre  2000-2012 há uma estabilização e as médias das coberturas vacinais ficam próximas de 80%**. Após 2012 vemos um aumento na cobertura (com valores médios acima de 80%), porém, há uma **queda em 2016 para uma cobertura média de 52.64%**. Os valores voltam a subir tendo uma média de 72.65% em 2018.
#
# - Esse tipo de informação é preocupante, pois **baixas coberturas** alcançadas para as principais vacinas do Calendário Nacional de Vacinação representam uma **ameaça real de retorno de doenças comuns no passado**, como o sarampo e a poliomielite (paralisia infantil).
#
# - Inclusive, **em 2018 tivemos o retorno do Sarampo**, com o registro de 10.274 casos no País. O País enfrentou dois surtos da doença: no Amazonas e em Roraima. Além disso, casos isolados foram notificados em outros Estados. E nós, claramente, tivemos esses casos de sarampo no Brasil porque não tínhamos cobertura de vacinação adequada.
#
# - Em relação à **Febre Amarela**, a **cobertura vacinal só é alta na Região Norte, na Região Nordeste no Maranhão, Bahia e na Região Centro-Oeste, em todos os Estados exceto no Distrito Federal**.
#
#   Considerando essas recomendações do Ministério da saúde, por serem áreas endêmicas, **A cobertura não é ideal no Espírito Santo e no Distrito Federal, onde as coberturas não chegam a 50%.**
#
# - No caso do **Sarampo**, a situação é preocupante no **Distrito Federal**, que teve **cobertura vacinal de 5.74%**.
#
# - **São Paulo, Ceará e Pernambuco são os Estados com maior cobertura vacinal contra o sarampo, chegando perto de 100%.**
# Na **Vacinação contra Poliomelite (4 anos)**, as **coberturas vacinais são péssimas em grande parte do País**, com **cobertura mínima de 27.98% e cobertura média de 60.37%**. Os **piores cenários são vistos em Amapá, Pará, Maranhão, Acre, Bahia e Rio Grande do Norte, onde a vacinação não chega nem a 50% de cobertura.**
#
# - A **Tetra Viral (SRC + VZ: contra sarampo, caxumba, rubéola e varicela) não alcançou ao menos 80% de cobertura vacinal em nenhuma das Unidades da Federação**. Os melhores valores de cobertura se concentram nas Regiões Sul e Centro-Oeste e na  Região Norte nos Estados: Rondônia, Roraima, Tocantins, Amazonas e Amapá.
#
# - Quando analisamos os valores de média vemos que os Imunobiológicos com maiores % de cobertura vacinal são:
#
#   BCG
#
#   Tríplice Viral D1
#
#   Poliomielite
#
#   DTP
#
# - Quando analisamos os valores de média vemos que os Imunobiológicos com % de Cobertura vacinal abaixo de 50% são:
#
#   Febre Amarela
#
#   Dupla adulto e tríplice acelular gestante
#
#   dTpa gestante
#
#   DTP REF (4 e 6 anos)
#
#   Haemophilus influenzae b
#
# - A **vacina BCG**, que previne a tuberculose, apresenta a maior cobertura vacinal, que é ótima em todas as Unidades da Federação.
# Dados apresentados pelo [Ministério da Saúde](https://agenciabrasil.ebc.com.br/saude/noticia/2019-09/bcg-e-unica-vacina-atingir-meta-de-imunizacao-desde-2017)  mostram que a BCG **foi a única vacina a alcançar a cobertura vacinal pretendida nos anos de 2017 e 2018**.
#
# - Em segundo lugar temos a **vacina contra poliomielite**, **porém a cobertura não chega a 100% em todos os Estados**. A maioria dos Estados da Região Norte (exceto Tocantins) não atinge os 100% de cobertura e alguns Estados do Nordeste se encontram em uma situação similar: Maranhão, Piauí, Ceará, Alagoas e Bahia.
#
# - Enquanto isso, a vacina **Tríplice viral apresenta ótima cobertura na primeira dose, mas quando olhamos a segunda dose vemos que o cenário muda completamente**, principalmente na região Norte, onde a melhor cobertura é em Rondônia com 82.36%. No Acre, por exemplo, a cobertura cai para 54.31%.
#
# - A queda da cobertura vacinal pode estar relacionada com a hesitação à vacinação, definida como atraso na aceitação ou recusa das vacinas recomendadas, apesar da sua disponibilidade nos serviços de saúde.Os  **principais motivos da hesitação à vacinação são falta de confiança quanto à eficácia/segurança da vacina e preocupações com eventos adversos**.
#
#
#  ## Parte II
# - O **papilomavírus humano** (HPV) é **uma das infecções sexualmente transmissíveis mais frequentes no mundo**. A persistência da infecção por alguns tipos de HPV pode evoluir para o **câncer do colo do útero**, doença que registra milhares de  novos casos por ano. **Uma das principais estratégias para prevenção desse tipo de câncer é a vacinação.**
#
# - Quando analisamos a vacinação contra o HPV é possível observar que no caso da vacinação no **sexo feminino os valores mais altos de doses aplicadas se concentram no ano inicial da campanha de vacinação (2014)** e as **doses aplicadas foram caindo ao longo do tempo, apresentando uma queda abrupta em 2016**. Em 2017 houve um pequeno aumento, mas as doses voltaram novamente a cair. Enquanto isso, **no caso das doses aplicadas no sexo masculino, as doses parecem ter começado a ser aplicadas somente em 2017, porém em 2018 as doses começam a declinar**.
#
# - **No período de 2014 a 2016 a vacinação estava ocorrendo de fato somente sexo feminino e que a vacinação era relacionada ao tamanho crescente da população**.
# Portanto, **quanto maior o número de habitantes, maior o número de doses aplicadas,** exceto em poucos pontos que ficariam fora de uma reta, caso fosse inserida uma reta nesses gráficos.
#
# - **Em 2017, vemos que a vacinação estava ocorrendo nos sexos feminino e masculino, de forma proporcional à população**, porém nos **anos seguintes vemos que começa a ocorrer uma dispersão nos pontos, indicando que a aplicação de doses começou a não estar tão relacionada.**
# Ao analisar a proporcionalidade de doses aplicadas pela população, de cada Unidade da Federação, é possível observar que **em 2017 havia uma proporção mais homogênea.**
#
# - **Em 2018 há uma série de discrepâncias, principalmente no sexo feminino, onde temos mais doses sendo aplicadas em Roraima, Amazonas e Paraná. Nos dados do sexo masculino há mais doses sendo aplicadas no Paraná, Roraima, Amazonas e Maranhão.**
#
# - Essas **heterogeneidades na proporção** de doses aplicadas podem estar associadas a **políticas públicas estaduais distintas**, que **afetam a disponibilidade de vacinas para a população**.
#
#
# - A análise de doses aplicadas por faixas etárias mostra que a **vacinação foi maior na faixa etária de 9 e 11 anos no sexo femino**, e que **abrangeu a faixa etária entre 9-14 anos**.
#
#
# - No caso do **sexo masculino a vacinação abrangeu a faixa etária entre 11-14 anos, porém foi maior aos 11 e 12 anos de idade.**
#
#
# - As **doses acima de 14 anos**, provavelmente, estão relacionadas ao fato da **vacina ter sido disponibilizada para as mulheres e homens até 26 anos de idade** vivendo com HIV/AIDS, transplantados de órgãos sólidos, de medula óssea e pacientes oncológicos.
#
# - A **discrepância entre vacinação nos sexos femino de masculino e a queda na aplicação de doses** mostra que a mídia social tem importante papel na disseminação das informações e é uma das maneiras de divulgar recomendações de saúde. Mas destaca-se que a **falta de informações e/ou as informações falsas sobre a vacina HPV ampliam a dificuldade de adesão à vacinação**.
#
# - Apesar da distribuição gratuita da vacina contra HPV, os resultados mostrados neste projeto e em estudos anteriores indicam que existe uma dificuldade na adesão nessa campanha de vacinação, principalmente no sexo masculino. **Os resultados mostram que os  gestores estaduais precisam planejar estratégias específicas para cada território e tentar de alguma forma ampliar essa vacinação.**
#
# - A vacina mais utilizada atualmente é a quadrivalente, que hoje é recomendada para meninas e mulheres de nove a 45 anos e meninos e homens de nove a 26 anos de idade. Porém, **além das fake news, diversos fatores para baixa vacinação têm sido associados ao baixo nível educacional, baixa renda, residência em zona rural, baixo acesso à informação e aos serviços de saúde e barreiras interpostas por dogmas religiosos**.
#
# - Apesar da queda na resposta imunológica com o passar dos anos, **adultos que não foram expostos ao vírus podem se vacinar**. Por esse motivo, o **Ministério da Saúde chegou a ofertar a vacina para adultos até os 26 anos.**
# Para aqueles **acima dessa idade, é necessário se vacinar na rede privada**. Devido ao alto preço das doses na rede privada, a vacina se torna acessível apenas para uma pequena parcela da população brasileira.
# - **Em conclusão, seria pertinente ampliar a vacinação contra HPV para adultos, já que a maior parte da população não tem acesso à rede privada.**

# %% [markdown]
# <a name="final"></a>
# #**Considerações finais**
#
# O que pode explicar a diminuição na cobertura vacinal nos últimos anos?
# Essa cobertura não é simplesmente um número. Sem cobertura vacinal, nós estamos suscetíveis a todas essas doenças.
#
# Nós sabemos que nosso país oferece diversos imunobiológicos gratuitamente no calendário nacional e que essa distribuição abrange recém-nascidos, crianças, adolescentes, adultos, idosos e povos indígenas.
#
# Minha opinião como Bióloga e Cientista é que a circulação crescente de notícias falsas sobre vacinas, que têm ocorrido nas redes sociais e aplicativos como WhatsApp, trouxe um enorme obscurantismo, que vem assolando nossa sociedade.
# Mesmo com evidências científicas de que as vacinas são seguras, alguns pais e responsáveis simplesmente optam por não levarem seus filhos para serem vacinados.
#
# Essa questão se tornou ainda mais evidente desde 2020, com o surgimento da pandemia de SARS-CoV-2, onde ocorreu uma disseminação massiva de fake news, sobre medicações e vacinação. Entramos num momento extremamente crítico e preocupante, onde o próprio presidente do Brasil, faz propaganda contra a vacinação.
#
# É necessária uma comunicação efetiva dos órgãos de saúde com a população. Não podemos permitir que doenças que foram erradicadas anos atrás retornem.
# Todos precisam entender que **Vacinas Salvam Vidas**!

# %% [markdown]
# <a name="ref"></a>
# #**Referências**
#
# [Agência Brasil - Casos de Sarampo no Brasil](https://agenciabrasil.ebc.com.br/saude/noticia/2019-01/brasil-tem-10274-casos-confirmados-de-sarampo)
#
# [As razões da Queda da Vacinação - Revista FAPESP](https://revistapesquisa.fapesp.br/as-razoes-da-queda-na-vacinacao/)
#
# [ Campanha - Programa Nacional de Imunizações](https://portalarquivos.saude.gov.br/campanhas/pni/o-que-e.html)
#
# [Cobertura da Vacina Papilomavírus Humano (HPV) no Brasil: Heterogeneidade Espacial e entre Coortes Etárias](https://www.scielo.br/j/rbepid/a/TStbZmwdZTG3rmZZFsqvNFx/?lang=pt)
#
# [Febre Amarela: Guia para  Profissionais de Saúde](https://portalarquivos2.saude.gov.br/images/pdf/2018/janeiro/18/Guia-febre-amarela-2018.pdf)
#
# [Fiocruz - Movimento Antivacina e Suas Ameaças](https://portal.fiocruz.br/video/movimento-antivacina-e-suas-ameacas-sala-de-convidados)
#
# [Fiocruz - Com fake news, discurso antivacina se espalha nas redes](https://portal.fiocruz.br/noticia/com-fake-news-discurso-antivacina-se-espalha-nas-redes)
#
# [Informe Técnico Sobre a Vacina Papilomavírus Humano (HPV) na Atenção Básica](
# https://portalarquivos2.saude.gov.br/images/pdf/2015/junho/26/Informe-T--cnico-Introdu----o-vacina-HPV-18-2-2014.pdf)
#
# [Instituto Nacional De Câncer - Atlas da Mortalidade](https://mortalidade.inca.gov.br/MortalidadeWeb/)
#
# [Instituto Nacional do Câncer - Controle do Câncer de Colo do Útero](https://www.inca.gov.br/controle-do-cancer-do-colo-do-utero/conceito-e-magnitude)
#
# [Instituto Nacional do Câncer - Para que Servem as Vacinas Contra o HPV?](https://www.inca.gov.br/perguntas-frequentes/para-que-servem-vacinas-contra-o-hpv)
#
# [Ministério da Saúde começa a vacinar meninos contra HPV em 2017](https://www.saude.go.gov.br/noticias/3705-ministerio-da-saude-comeca-a-vacinar-meninos-contra-hpv-em-2017)
#
# [PNI- Programa Nacional de Imunizações, Boletim Informativo: Vacinação contra HPV](https://portalarquivos2.saude.gov.br/images/pdf/2017/julho/28/Boletim-informativo.pdf)
#
# [Queda da Cobertura Vacinal no Brasil](https://portal.fiocruz.br/noticia/revista-radis-aborda-queda-da-cobertura-vacinal-no-brasil)
#
# [Tabnet - DATASUS, Cobertura Vacinal](http://tabnet.datasus.gov.br/tabdata/livroidb/Com2007/Com_F13.pdf)
#
# [Tabnet - DATASUS,  Imunizações: Cobertura -  Notas Técnicas](http://tabnet.datasus.gov.br/cgi/pni/%5Ccpnidescr.htm)
#
# [World Health Organization -  International Agency for Research on Cancer](https://www.iarc.who.int/)

# %% [markdown]
# <a name="doc"></a>
# #**Documentação**
#
# [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# [Matplotlib](https://matplotlib.org/)
#
# [Numpy](https://numpy.org/)
#
# [Pandas](https://pandas.pydata.org/)
#
# [Requests](https://docs.python-requests.org/en/master/)
#
# [Seaborn](https://seaborn.pydata.org/)

# %% [markdown]
# <a name="agra"></a>
# #**Agradecimentos**
#
# Gostaria de deixar meu agradecimento aos instrutores do módulo 2: Thiago Gonçalves e Guilherme Silveira.
#
# Ao pessoal do Scuba team e do Discord, que sempre trazem excelentes discussões e ideias.
#
# Também gostaria de agradecer ao Junior Torres e Carolina Dias, que sempre têm ideias inspiradoras, e me deram muitas dicas de como melhorar as visualizações gráficas.
#
#
# <p align="center"><img src="https://media.giphy.com/media/M9NbzZjAcxq9jS9LZJ/giphy.gif"</p>

# %% [markdown]
# #**Onde encontrar meu trabalho**
#
# [LinkedIn](https://www.linkedin.com/in/valqu%C3%ADria-alencar-786a8911b/)
#
# [ResearchGate](https://www.researchgate.net/profile/Valquiria-Alencar)
#
# [Currículo lattes](http://lattes.cnpq.br/7742338443535710)
